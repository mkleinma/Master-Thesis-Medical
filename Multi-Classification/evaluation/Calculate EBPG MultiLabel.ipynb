# %% [markdown]
# # Calculate EPG (Precision) over all five folds

# %%
from libraries_multilabel.energyPointGame import energy_point_game_mask
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID

# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"

# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos\no_nosamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                            contribution_map[contribution_map < 0] = 0
                            
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_mask(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.1880       0.1852         0.2004            497              114
#        Atelectasis          0.3591       0.3756         0.3494             14               24
#      Calcification          0.2033       0.2764         0.2024              1               90
#       Cardiomegaly          0.2371       0.2364         0.2389            329              131
#      Consolidation          0.3594       0.4531         0.3115             24               47
#                ILD          0.3996       0.4838         0.3856             11               66
#       Infiltration          0.3005       0.3574         0.2797             33               90
#       Lung Opacity          0.2616       0.3418         0.1911            124              141
#        Nodule/Mass          0.1664       0.1784         0.1645             23              142
#       Other lesion          0.2310       0.2870         0.2182             42              185
#   Pleural effusion          0.2900       0.3432         0.1881            136               71
# Pleural thickening          0.2026       0.2085         0.1961            209              188
#       Pneumothorax          0.4488       0.5211         0.4295              4               15
# Pulmonary fibrosis          0.2113       0.2342         0.1808            185              139
#            Average          0.2756       0.3202         0.2526           1632             1443
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.1966       0.1859         0.2338            475              137
#        Atelectasis          0.3275       0.4114         0.3112              6               31
#      Calcification          0.2131       0.2561         0.2031             17               73
#       Cardiomegaly          0.2495       0.2528         0.2385            355              105
#      Consolidation          0.3846       0.5177         0.3602             11               60
#                ILD          0.4403       0.5909         0.4156             11               67
#       Infiltration          0.3006       0.4240         0.2568             32               90
#       Lung Opacity          0.2788       0.3937         0.2064            102              162
#        Nodule/Mass          0.2051       0.1579         0.2140             26              139
#       Other lesion          0.2112       0.3568         0.1890             30              197
#   Pleural effusion          0.3017       0.3862         0.1883            118               88
# Pleural thickening          0.2045       0.2385         0.1820            158              238
#       Pneumothorax          0.4192       0.2756         0.4361              2               17
# Pulmonary fibrosis          0.2095       0.2428         0.1770            160              164
#            Average          0.2816       0.3350         0.2580           1503             1568
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.1852       0.1789         0.2229            533               88
#        Atelectasis          0.3173       0.3742         0.2933             11               26
#      Calcification          0.1710       0.1948         0.1693              6               84
#       Cardiomegaly          0.2207       0.2213         0.2128            428               32
#      Consolidation          0.3522       0.4799         0.2897             23               47
#                ILD          0.4258       0.5504         0.3760             22               55
#       Infiltration          0.2913       0.3824         0.2222             53               70
#       Lung Opacity          0.2614       0.3500         0.1930            115              149
#        Nodule/Mass          0.1934       0.2217         0.1912             12              153
#       Other lesion          0.2230       0.2682         0.2068             60              167
#   Pleural effusion          0.3091       0.3824         0.2379            102              105
# Pleural thickening          0.2063       0.2393         0.1730            199              197
#       Pneumothorax          0.4486       0.4608         0.4472              2               18
# Pulmonary fibrosis          0.2002       0.2216         0.1650            201              122
#            Average          0.2718       0.3233         0.2429           1767             1313
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2015       0.1980         0.2258            536               76
#        Atelectasis          0.3123       0.4417         0.2708              9               28
#      Calcification          0.1932       0.0000         0.1932              0               90
#       Cardiomegaly          0.2495       0.2406         0.2963            387               73
#      Consolidation          0.3540       0.4850         0.3015             20               50
#                ILD          0.4001       0.5428         0.3859              7               70
#       Infiltration          0.3123       0.4150         0.2676             37               85
#       Lung Opacity          0.2626       0.3108         0.1861            162              102
#        Nodule/Mass          0.2066       0.2107         0.2044             59              106
#       Other lesion          0.2407       0.3689         0.2302             17              209
#   Pleural effusion          0.2760       0.3129         0.1882            145               61
# Pleural thickening          0.2066       0.2213         0.1810            252              144
#       Pneumothorax          0.4385       0.6764         0.3939              3               16
# Pulmonary fibrosis          0.2160       0.2401         0.1905            166              157
#            Average          0.2764       0.3332         0.2511           1800             1267
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2048       0.2074         0.1855            538               73
#        Atelectasis          0.3483       0.4380         0.3151             10               27
#      Calcification          0.2075       0.2579         0.2046              5               86
#       Cardiomegaly          0.2552       0.2535         0.2607            353              107
#      Consolidation          0.3650       0.5242         0.3187             16               55
#                ILD          0.4416       0.5443         0.4146             16               61
#       Infiltration          0.3129       0.4670         0.2466             37               86
#       Lung Opacity          0.2622       0.3669         0.2102             88              177
#        Nodule/Mass          0.1916       0.2888         0.1790             19              147
#       Other lesion          0.2487       0.2934         0.2419             30              197
#   Pleural effusion          0.2637       0.3466         0.1956             93              113
# Pleural thickening          0.2017       0.2486         0.1483            211              185
#       Pneumothorax          0.4593       0.4535         0.4604              3               16
# Pulmonary fibrosis          0.2127       0.2780         0.1676            132              191
#            Average          0.2839       0.3549         0.2535           1551             1521
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2011       0.2006         0.2050            535               76
#        Atelectasis          0.3872       0.4202         0.3506             20               18
#      Calcification          0.2268       0.2909         0.2180             11               80
#       Cardiomegaly          0.2697       0.2659         0.2860            373               87
#      Consolidation          0.3929       0.4733         0.3406             28               43
#                ILD          0.4141       0.5469         0.3820             15               62
#       Infiltration          0.3377       0.4316         0.2988             36               87
#       Lung Opacity          0.2750       0.3881         0.2252             81              184
#        Nodule/Mass          0.1823       0.2170         0.1732             34              131
#       Other lesion          0.2481       0.2463         0.2494             94              133
#   Pleural effusion          0.3023       0.3685         0.2180            116               91
# Pleural thickening          0.2216       0.2642         0.1889            172              225
#       Pneumothorax          0.4919       0.5973         0.4638              4               15
# Pulmonary fibrosis          0.2366       0.3004         0.2015            115              209
#            Average          0.2991       0.3579         0.2715           1634             1441
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.1872       0.1762         0.2416            509              103
#        Atelectasis          0.3173       0.2992         0.3194              4               33
#      Calcification          0.2012       0.2752         0.1968              5               85
#       Cardiomegaly          0.2412       0.2311         0.2715            345              115
#      Consolidation          0.3970       0.5006         0.3506             22               49
#                ILD          0.4401       0.6080         0.4210              8               70
#       Infiltration          0.3134       0.4591         0.2777             24               98
#       Lung Opacity          0.2769       0.3819         0.1894            120              144
#        Nodule/Mass          0.2116       0.2616         0.1961             39              126
#       Other lesion          0.2105       0.2255         0.1746            160               67
#   Pleural effusion          0.3035       0.3670         0.2233            115               91
# Pleural thickening          0.2036       0.2268         0.1869            165              231
#       Pneumothorax          0.4309       0.3505         0.4459              3               16
# Pulmonary fibrosis          0.2120       0.2363         0.1832            176              148
#            Average          0.2819       0.3285         0.2627           1695             1376
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.1912       0.1863         0.2074            479              142
#        Atelectasis          0.3505       0.3438         0.3530             10               27
#      Calcification          0.1876       0.2300         0.1722             24               66
#       Cardiomegaly          0.2468       0.2498         0.2344            370               90
#      Consolidation          0.3694       0.4883         0.3313             17               53
#                ILD          0.4546       0.5260         0.4115             29               48
#       Infiltration          0.3011       0.3677         0.2702             39               84
#       Lung Opacity          0.2740       0.4245         0.2278             62              202
#        Nodule/Mass          0.2034       0.1933         0.2057             30              135
#       Other lesion          0.2314       0.2985         0.2099             55              172
#   Pleural effusion          0.3194       0.3800         0.2191            129               78
# Pleural thickening          0.2111       0.2327         0.1744            249              147
#       Pneumothorax          0.4299       0.0000         0.4299              0               20
# Pulmonary fibrosis          0.2244       0.2324         0.2167            159              164
#            Average          0.2853       0.2967         0.2617           1652             1428
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.1933       0.1880         0.2073            443              169
#        Atelectasis          0.2996       0.3610         0.2577             15               22
#      Calcification          0.1870       0.2437         0.1799             10               80
#       Cardiomegaly          0.2507       0.2371         0.2701            271              189
#      Consolidation          0.3512       0.3878         0.3023             40               30
#                ILD          0.3887       0.5002         0.3546             18               59
#       Infiltration          0.3047       0.3505         0.2315             75               47
#       Lung Opacity          0.2603       0.3208         0.1888            143              121
#        Nodule/Mass          0.2052       0.2184         0.1970             63              102
#       Other lesion          0.2299       0.2986         0.1971             73              153
#   Pleural effusion          0.2722       0.3082         0.1653            154               52
# Pleural thickening          0.1934       0.1994         0.1630            331               65
#       Pneumothorax          0.4113       0.6152         0.3385              5               14
# Pulmonary fibrosis          0.2099       0.2340         0.1626            214              109
#            Average          0.2684       0.3188         0.2297           1855             1212
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.1787       0.1795         0.1746            507              104
#        Atelectasis          0.3565       0.3590         0.3549             14               23
#      Calcification          0.1882       0.3870         0.1815              3               88
#       Cardiomegaly          0.2432       0.2386         0.2568            342              118
#      Consolidation          0.3665       0.4155         0.3327             29               42
#                ILD          0.4283       0.4829         0.3873             33               44
#       Infiltration          0.3035       0.3502         0.2305             75               48
#       Lung Opacity          0.2621       0.3232         0.1905            143              122
#        Nodule/Mass          0.1833       0.2018         0.1782             36              130
#       Other lesion          0.2343       0.3044         0.2240             29              198
#   Pleural effusion          0.2604       0.2953         0.1645            151               55
# Pleural thickening          0.1946       0.1997         0.1789            300               96
#       Pneumothorax          0.4830       0.5353         0.4769              2               17
# Pulmonary fibrosis          0.2089       0.2137         0.1868            265               58
#            Average          0.2780       0.3204         0.2513           1929             1143
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.1928 ± 0.0025
# Correct   : 0.1886 ± 0.0025
# Incorrect : 0.2104 ± 0.0033
#
# Class: Atelectasis
# Proportion: 0.3376 ± 0.0047
# Correct   : 0.3824 ± 0.0258
# Incorrect : 0.3175 ± 0.0096
#
# Class: Calcification
# Proportion: 0.1979 ± 0.0003
# Correct   : 0.2412 ± 0.0442
# Incorrect : 0.1921 ± 0.0024
#
# Class: Cardiomegaly
# Proportion: 0.2464 ± 0.0040
# Correct   : 0.2427 ± 0.0018
# Incorrect : 0.2566 ± 0.0072
#
# Class: Consolidation
# Proportion: 0.3692 ± 0.0062
# Correct   : 0.4725 ± 0.0194
# Incorrect : 0.3239 ± 0.0076
#
# Class: ILD
# Proportion: 0.4233 ± 0.0018
# Correct   : 0.5376 ± 0.0048
# Incorrect : 0.3934 ± 0.0021
#
# Class: Infiltration
# Proportion: 0.3078 ± 0.0043
# Correct   : 0.4005 ± 0.0087
# Incorrect : 0.2582 ± 0.0036
#
# Class: Lung Opacity
# Proportion: 0.2675 ± 0.0022
# Correct   : 0.3602 ± 0.0075
# Incorrect : 0.2009 ± 0.0035
#
# Class: Nodule/Mass
# Proportion: 0.1949 ± 0.0023
# Correct   : 0.2150 ± 0.0035
# Incorrect : 0.1903 ± 0.0003
#
# Class: Other lesion
# Proportion: 0.2309 ± 0.0000
# Correct   : 0.2948 ± 0.0201
# Incorrect : 0.2141 ± 0.0031
#
# Class: Pleural effusion
# Proportion: 0.2898 ± 0.0017
# Correct   : 0.3490 ± 0.0052
# Incorrect : 0.1988 ± 0.0008
#
# Class: Pleural thickening
# Proportion: 0.2046 ± 0.0003
# Correct   : 0.2279 ± 0.0033
# Incorrect : 0.1773 ± 0.0012
#
# Class: Pneumothorax
# Proportion: 0.4461 ± 0.0033
# Correct   : 0.4486 ± 0.0289
# Incorrect : 0.4322 ± 0.0012
#
# Class: Pulmonary fibrosis
# Proportion: 0.2142 ± 0.0042
# Correct   : 0.2433 ± 0.0000
# Incorrect : 0.1832 ± 0.0070
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.2802 ± 0.0023
# Correct   : 0.3289 ± 0.0044
# Incorrect : 0.2535 ± 0.0019

# %% [markdown]
# # Calculate EPG (Precision) across both seeds

# %%
from libraries_multilabel.energyPointGame import energy_point_game_mask
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID

# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"

# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos\light_oversamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                            contribution_map[contribution_map < 0] = 0
                            
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_mask(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2426       0.2416         0.2528            555               56
#        Atelectasis          0.3714       0.3824         0.3643             15               23
#      Calcification          0.2419       0.3042         0.2296             15               76
#       Cardiomegaly          0.3057       0.3070         0.2954            412               48
#      Consolidation          0.3813       0.4048         0.3685             25               46
#                ILD          0.4165       0.5235         0.3862             17               60
#       Infiltration          0.3152       0.3397         0.3000             47               76
#       Lung Opacity          0.2814       0.3793         0.2181            104              161
#        Nodule/Mass          0.1884       0.1923         0.1869             47              118
#       Other lesion          0.2744       0.3289         0.2590             50              177
#   Pleural effusion          0.3158       0.3712         0.2438            117               90
# Pleural thickening          0.2305       0.2323         0.2288            194              203
#       Pneumothorax          0.4958       0.6182         0.4631              4               15
# Pulmonary fibrosis          0.2337       0.2287         0.2386            162              162
#            Average          0.3068       0.3467         0.2882           1764             1311
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2481       0.2414         0.3054            548               64
#        Atelectasis          0.3675       0.3632         0.3698             13               24
#      Calcification          0.2521       0.3233         0.2262             24               66
#       Cardiomegaly          0.3032       0.3010         0.3232            415               45
#      Consolidation          0.4183       0.4639         0.3964             23               48
#                ILD          0.4701       0.4748         0.4682             23               55
#       Infiltration          0.3143       0.3999         0.2710             41               81
#       Lung Opacity          0.3054       0.3950         0.2249            125              139
#        Nodule/Mass          0.2226       0.2190         0.2238             43              122
#       Other lesion          0.2499       0.2903         0.2299             75              152
#   Pleural effusion          0.3337       0.3850         0.2402            133               73
# Pleural thickening          0.2397       0.2427         0.2358            226              170
#       Pneumothorax          0.4546       0.5484         0.4295              4               15
# Pulmonary fibrosis          0.2367       0.2411         0.2325            159              165
#            Average          0.3154       0.3492         0.2983           1852             1219
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2409       0.2388         0.2553            542               79
#        Atelectasis          0.3798       0.4056         0.3715              9               28
#      Calcification          0.2049       0.2652         0.1947             13               77
#       Cardiomegaly          0.2986       0.2977         0.3062            412               48
#      Consolidation          0.3591       0.5193         0.3226             13               57
#                ILD          0.4483       0.5557         0.4131             19               58
#       Infiltration          0.2974       0.4217         0.2480             35               88
#       Lung Opacity          0.2885       0.3923         0.2231            102              162
#        Nodule/Mass          0.2202       0.2496         0.2131             32              133
#       Other lesion          0.2527       0.3223         0.2345             47              180
#   Pleural effusion          0.3297       0.3745         0.2557            129               78
# Pleural thickening          0.2281       0.2355         0.2211            193              203
#       Pneumothorax          0.4425       0.4859         0.4316              4               16
# Pulmonary fibrosis          0.2264       0.2259         0.2268            165              158
#            Average          0.3012       0.3564         0.2798           1715             1365
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2395       0.2370         0.2569            534               78
#        Atelectasis          0.3244       0.3352         0.3209              9               28
#      Calcification          0.2179       0.2696         0.2092             13               77
#       Cardiomegaly          0.3112       0.3063         0.3366            386               74
#      Consolidation          0.3939       0.4545         0.3661             22               48
#                ILD          0.4282       0.5213         0.3977             19               58
#       Infiltration          0.3268       0.3671         0.3064             41               81
#       Lung Opacity          0.2953       0.3574         0.2451            118              146
#        Nodule/Mass          0.2335       0.2465         0.2296             38              127
#       Other lesion          0.2686       0.3209         0.2497             60              166
#   Pleural effusion          0.3099       0.3506         0.2471            125               81
# Pleural thickening          0.2298       0.2320         0.2278            187              209
#       Pneumothorax          0.4081       0.5228         0.3412              7               12
# Pulmonary fibrosis          0.2401       0.2474         0.2336            151              172
#            Average          0.3019       0.3406         0.2834           1710             1357
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2306       0.2299         0.2373            551               60
#        Atelectasis          0.3862       0.4733         0.3540             10               27
#      Calcification          0.2272       0.3034         0.2058             20               71
#       Cardiomegaly          0.2997       0.2914         0.3566            401               59
#      Consolidation          0.4021       0.4730         0.3780             18               53
#                ILD          0.4519       0.5893         0.4003             21               56
#       Infiltration          0.3221       0.4337         0.2702             39               84
#       Lung Opacity          0.2913       0.3752         0.2240            118              147
#        Nodule/Mass          0.2058       0.2160         0.2021             44              122
#       Other lesion          0.2733       0.3149         0.2638             42              185
#   Pleural effusion          0.2932       0.3524         0.2138            118               88
# Pleural thickening          0.2188       0.2076         0.2307            204              192
#       Pneumothorax          0.4884       0.7112         0.4622              2               17
# Pulmonary fibrosis          0.2292       0.2608         0.2019            150              173
#            Average          0.3086       0.3737         0.2858           1738             1334
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2207       0.2208         0.2200            538               73
#        Atelectasis          0.3964       0.4098         0.3876             15               23
#      Calcification          0.2382       0.3927         0.2191             10               81
#       Cardiomegaly          0.2802       0.2804         0.2797            354              106
#      Consolidation          0.3571       0.4032         0.3415             18               53
#                ILD          0.3924       0.4540         0.3628             25               52
#       Infiltration          0.3119       0.3575         0.2762             54               69
#       Lung Opacity          0.2740       0.3640         0.1935            125              140
#        Nodule/Mass          0.1854       0.2019         0.1821             27              138
#       Other lesion          0.2633       0.3276         0.2352             69              158
#   Pleural effusion          0.3123       0.3791         0.2335            112               95
# Pleural thickening          0.2308       0.2421         0.2171            218              179
#       Pneumothorax          0.4470       0.5785         0.4224              3               16
# Pulmonary fibrosis          0.2287       0.2292         0.2261            270               54
#            Average          0.2956       0.3458         0.2712           1838             1237
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2392       0.2315         0.3018            545               67
#        Atelectasis          0.3585       0.3517         0.3637             16               21
#      Calcification          0.2457       0.3609         0.2170             18               72
#       Cardiomegaly          0.2799       0.2751         0.2998            369               91
#      Consolidation          0.4130       0.4324         0.3931             36               35
#                ILD          0.4797       0.5227         0.4556             28               50
#       Infiltration          0.3216       0.4013         0.2813             41               81
#       Lung Opacity          0.2990       0.3673         0.2327            130              134
#        Nodule/Mass          0.2247       0.2331         0.2218             43              122
#       Other lesion          0.2433       0.2431         0.2436            138               89
#   Pleural effusion          0.3239       0.3715         0.2293            137               69
# Pleural thickening          0.2290       0.2276         0.2322            275              121
#       Pneumothorax          0.4491       0.4480         0.4494              5               14
# Pulmonary fibrosis          0.2347       0.2474         0.2258            133              191
#            Average          0.3101       0.3367         0.2962           1914             1157
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2390       0.2359         0.2626            548               73
#        Atelectasis          0.3838       0.4147         0.3723             10               27
#      Calcification          0.2136       0.2298         0.2120              8               82
#       Cardiomegaly          0.3033       0.3046         0.2917            414               46
#      Consolidation          0.3805       0.5077         0.3295             20               50
#                ILD          0.4665       0.5684         0.4083             28               49
#       Infiltration          0.3140       0.4211         0.2500             46               77
#       Lung Opacity          0.3014       0.3859         0.2276            123              141
#        Nodule/Mass          0.2320       0.2968         0.2132             37              128
#       Other lesion          0.2595       0.3156         0.2394             60              167
#   Pleural effusion          0.3529       0.4017         0.2652            133               74
# Pleural thickening          0.2471       0.2501         0.2426            240              156
#       Pneumothorax          0.4627       0.5775         0.4340              4               16
# Pulmonary fibrosis          0.2435       0.2405         0.2484            200              123
#            Average          0.3143       0.3679         0.2855           1871             1209
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2244       0.2243         0.2249            542               70
#        Atelectasis          0.3120       0.3895         0.2833             10               27
#      Calcification          0.2104       0.3152         0.1943             12               78
#       Cardiomegaly          0.2936       0.2868         0.3286            385               75
#      Consolidation          0.3851       0.4738         0.3445             22               48
#                ILD          0.4206       0.5011         0.3720             29               48
#       Infiltration          0.3222       0.3746         0.2870             49               73
#       Lung Opacity          0.2855       0.3503         0.2244            128              136
#        Nodule/Mass          0.2247       0.2338         0.2217             41              124
#       Other lesion          0.2626       0.3239         0.2424             56              170
#   Pleural effusion          0.3014       0.3473         0.2319            124               82
# Pleural thickening          0.2179       0.2247         0.2103            210              186
#       Pneumothorax          0.4267       0.7609         0.3641              3               16
# Pulmonary fibrosis          0.2324       0.2382         0.2260            168              155
#            Average          0.2942       0.3603         0.2682           1779             1288
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2363       0.2379         0.2193            559               52
#        Atelectasis          0.3742       0.3661         0.3761              7               30
#      Calcification          0.2331       0.3723         0.2056             15               76
#       Cardiomegaly          0.3055       0.3014         0.3366            406               54
#      Consolidation          0.4101       0.5065         0.3843             15               56
#                ILD          0.4600       0.5433         0.4307             20               57
#       Infiltration          0.3325       0.4542         0.2841             35               88
#       Lung Opacity          0.2952       0.3751         0.2358            113              152
#        Nodule/Mass          0.2101       0.1963         0.2147             41              125
#       Other lesion          0.2809       0.2973         0.2762             50              177
#   Pleural effusion          0.3002       0.3574         0.2266            116               90
# Pleural thickening          0.2211       0.2146         0.2296            225              171
#       Pneumothorax          0.4925       0.4924         0.4925              3               16
# Pulmonary fibrosis          0.2372       0.2600         0.2152            159              164
#            Average          0.3135       0.3553         0.2948           1764             1308
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.2361 ± 0.0042
# Correct   : 0.2339 ± 0.0038
# Incorrect : 0.2536 ± 0.0079
#
# Class: Atelectasis
# Proportion: 0.3654 ± 0.0004
# Correct   : 0.3891 ± 0.0028
# Incorrect : 0.3564 ± 0.0003
#
# Class: Calcification
# Proportion: 0.2285 ± 0.0003
# Correct   : 0.3137 ± 0.0205
# Incorrect : 0.2113 ± 0.0017
#
# Class: Cardiomegaly
# Proportion: 0.2981 ± 0.0056
# Correct   : 0.2952 ± 0.0055
# Incorrect : 0.3154 ± 0.0082
#
# Class: Consolidation
# Proportion: 0.3901 ± 0.0009
# Correct   : 0.4639 ± 0.0008
# Incorrect : 0.3624 ± 0.0039
#
# Class: ILD
# Proportion: 0.4434 ± 0.0004
# Correct   : 0.5254 ± 0.0075
# Incorrect : 0.4095 ± 0.0036
#
# Class: Infiltration
# Proportion: 0.3178 ± 0.0026
# Correct   : 0.3971 ± 0.0047
# Incorrect : 0.2774 ± 0.0017
#
# Class: Lung Opacity
# Proportion: 0.2917 ± 0.0007
# Correct   : 0.3742 ± 0.0057
# Incorrect : 0.2249 ± 0.0021
#
# Class: Nodule/Mass
# Proportion: 0.2147 ± 0.0006
# Correct   : 0.2285 ± 0.0038
# Incorrect : 0.2109 ± 0.0002
#
# Class: Other lesion
# Proportion: 0.2628 ± 0.0009
# Correct   : 0.3085 ± 0.0070
# Incorrect : 0.2474 ± 0.0000
#
# Class: Pleural effusion
# Proportion: 0.3173 ± 0.0008
# Correct   : 0.3691 ± 0.0023
# Incorrect : 0.2387 ± 0.0014
#
# Class: Pleural thickening
# Proportion: 0.2293 ± 0.0001
# Correct   : 0.2309 ± 0.0009
# Incorrect : 0.2276 ± 0.0012
#
# Class: Pneumothorax
# Proportion: 0.4567 ± 0.0011
# Correct   : 0.5744 ± 0.0029
# Incorrect : 0.4290 ± 0.0035
#
# Class: Pulmonary fibrosis
# Proportion: 0.2343 ± 0.0010
# Correct   : 0.2419 ± 0.0011
# Incorrect : 0.2275 ± 0.0008
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.3062 ± 0.0006
# Correct   : 0.3533 ± 0.0001
# Incorrect : 0.2851 ± 0.0020

# %%
from libraries_multilabel.energyPointGame import energy_point_game_mask
from libraries_multilabel.bcosconv2d import NormedConv2d
from pooling.flc_bcosconv2d import ModifiedFLCBcosConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID

# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"

# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.layer2[0].conv2 = ModifiedFLCBcosConv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2, transpose=True)
        model.layer2[0].downsample[0] = ModifiedFLCBcosConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), b=2, transpose=False)

        model.layer3[0].conv2 = ModifiedFLCBcosConv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2, transpose=True)
        model.layer3[0].downsample[0] = ModifiedFLCBcosConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), b=2, transpose=False)

        model.layer4[0].conv2 = ModifiedFLCBcosConv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2, transpose=True)
        model.layer4[0].downsample[0] = ModifiedFLCBcosConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), b=2, transpose=False)    

        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                            contribution_map[contribution_map < 0] = 0
                            
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_mask(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2326       0.2330         0.2303            514               97
#        Atelectasis          0.3712       0.3683         0.3730             15               23
#      Calcification          0.2294       0.8209         0.2228              1               90
#       Cardiomegaly          0.3149       0.3137         0.3171            300              160
#      Consolidation          0.3390       0.4380         0.2428             35               36
#                ILD          0.4289       0.5211         0.3390             38               39
#       Infiltration          0.3042       0.3633         0.2401             64               59
#       Lung Opacity          0.2575       0.3254         0.1959            126              139
#        Nodule/Mass          0.1733       0.2046         0.1723              5              160
#       Other lesion          0.2442       0.2935         0.2327             43              184
#   Pleural effusion          0.2818       0.3563         0.1888            115               92
# Pleural thickening          0.2048       0.2245         0.1863            192              205
#       Pneumothorax          0.3882       0.3877         0.3882              1               18
# Pulmonary fibrosis          0.2146       0.2419         0.1801            181              143
#            Average          0.2846       0.3637         0.2507           1630             1445
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2263       0.2254         0.2287            430              182
#        Atelectasis          0.3550       0.4863         0.3064             10               27
#      Calcification          0.2483       0.2965         0.2472              2               88
#       Cardiomegaly          0.2740       0.2758         0.2676            358              102
#      Consolidation          0.3733       0.4417         0.3338             26               45
#                ILD          0.4987       0.5453         0.4876             15               63
#       Infiltration          0.3115       0.4702         0.2424             37               85
#       Lung Opacity          0.2661       0.3532         0.1737            136              128
#        Nodule/Mass          0.1971       0.1506         0.2078             31              134
#       Other lesion          0.2095       0.2460         0.2005             45              182
#   Pleural effusion          0.3059       0.4163         0.1889            106              100
# Pleural thickening          0.2118       0.2492         0.1777            189              207
#       Pneumothorax          0.4249       0.4381         0.4214              4               15
# Pulmonary fibrosis          0.2261       0.2634         0.1823            175              149
#            Average          0.2949       0.3470         0.2619           1564             1507
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2401       0.2432         0.2179            544               77
#        Atelectasis          0.3441       0.3954         0.3300              8               29
#      Calcification          0.1994       0.2624         0.1973              3               87
#       Cardiomegaly          0.3078       0.3038         0.3330            397               63
#      Consolidation          0.3279       0.4731         0.2738             19               51
#                ILD          0.4778       0.5430         0.4565             19               58
#       Infiltration          0.3018       0.4245         0.2605             31               92
#       Lung Opacity          0.2646       0.3672         0.1978            104              160
#        Nodule/Mass          0.2027       0.2342         0.1986             19              146
#       Other lesion          0.2297       0.2667         0.2200             47              180
#   Pleural effusion          0.2981       0.3632         0.2298            106              101
# Pleural thickening          0.2130       0.2211         0.2025            224              172
#       Pneumothorax          0.4170       0.4112         0.4177              2               18
# Pulmonary fibrosis          0.2238       0.2570         0.1916            159              164
#            Average          0.2891       0.3404         0.2662           1682             1398
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2253       0.2287         0.2102            501              111
#        Atelectasis          0.3389       0.4402         0.3266              4               33
#      Calcification          0.2005       0.5720         0.1963              1               89
#       Cardiomegaly          0.3248       0.3249         0.3244            410               50
#      Consolidation          0.3485       0.4248         0.2525             39               31
#                ILD          0.4434       0.5902         0.4239              9               68
#       Infiltration          0.3190       0.4642         0.2455             41               81
#       Lung Opacity          0.2644       0.3250         0.1808            153              111
#        Nodule/Mass          0.2060       0.2411         0.1975             32              133
#       Other lesion          0.2351       0.3243         0.2021             61              165
#   Pleural effusion          0.2782       0.3488         0.2224             91              115
# Pleural thickening          0.2038       0.2383         0.1846            142              254
#       Pneumothorax          0.4046       0.3902         0.4054              1               18
# Pulmonary fibrosis          0.2151       0.2684         0.1868            112              211
#            Average          0.2863       0.3701         0.2542           1597             1470
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2335       0.2404         0.2136            453              158
#        Atelectasis          0.3682       0.5108         0.3349              7               30
#      Calcification          0.2155       0.4674         0.2099              2               89
#       Cardiomegaly          0.2939       0.2882         0.3247            388               72
#      Consolidation          0.3501       0.4631         0.2764             28               43
#                ILD          0.4941       0.6136         0.4521             20               57
#       Infiltration          0.3111       0.4705         0.2763             22              101
#       Lung Opacity          0.2616       0.3620         0.1925            108              157
#        Nodule/Mass          0.1883       0.0795         0.1903              3              163
#       Other lesion          0.2306       0.3066         0.2057             56              171
#   Pleural effusion          0.2810       0.3510         0.1729            125               81
# Pleural thickening          0.2016       0.2252         0.1671            235              161
#       Pneumothorax          0.4461       0.6411         0.4096              3               16
# Pulmonary fibrosis          0.2272       0.2748         0.1995            119              204
#            Average          0.2931       0.3782         0.2590           1569             1503
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2326       0.2330         0.2303            514               97
#        Atelectasis          0.3712       0.3683         0.3730             15               23
#      Calcification          0.2294       0.8209         0.2228              1               90
#       Cardiomegaly          0.3149       0.3137         0.3171            300              160
#      Consolidation          0.3390       0.4380         0.2428             35               36
#                ILD          0.4289       0.5211         0.3390             38               39
#       Infiltration          0.3042       0.3633         0.2401             64               59
#       Lung Opacity          0.2575       0.3254         0.1959            126              139
#        Nodule/Mass          0.1733       0.2046         0.1723              5              160
#       Other lesion          0.2442       0.2935         0.2327             43              184
#   Pleural effusion          0.2819       0.3563         0.1888            115               92
# Pleural thickening          0.2048       0.2245         0.1863            192              205
#       Pneumothorax          0.3882       0.3877         0.3882              1               18
# Pulmonary fibrosis          0.2146       0.2419         0.1801            181              143
#            Average          0.2846       0.3637         0.2507           1630             1445
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2263       0.2254         0.2287            430              182
#        Atelectasis          0.3550       0.4863         0.3064             10               27
#      Calcification          0.2483       0.2965         0.2472              2               88
#       Cardiomegaly          0.2740       0.2758         0.2676            358              102
#      Consolidation          0.3733       0.4417         0.3338             26               45
#                ILD          0.4987       0.5453         0.4876             15               63
#       Infiltration          0.3115       0.4702         0.2424             37               85
#       Lung Opacity          0.2661       0.3532         0.1737            136              128
#        Nodule/Mass          0.1971       0.1506         0.2078             31              134
#       Other lesion          0.2095       0.2460         0.2005             45              182
#   Pleural effusion          0.3059       0.4163         0.1889            106              100
# Pleural thickening          0.2118       0.2492         0.1777            189              207
#       Pneumothorax          0.4249       0.4381         0.4214              4               15
# Pulmonary fibrosis          0.2261       0.2634         0.1823            175              149
#            Average          0.2949       0.3470         0.2619           1564             1507
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2401       0.2432         0.2179            544               77
#        Atelectasis          0.3441       0.3954         0.3300              8               29
#      Calcification          0.1994       0.2624         0.1973              3               87
#       Cardiomegaly          0.3078       0.3038         0.3330            397               63
#      Consolidation          0.3279       0.4731         0.2738             19               51
#                ILD          0.4778       0.5430         0.4565             19               58
#       Infiltration          0.3018       0.4245         0.2605             31               92
#       Lung Opacity          0.2646       0.3672         0.1978            104              160
#        Nodule/Mass          0.2027       0.2342         0.1986             19              146
#       Other lesion          0.2297       0.2667         0.2200             47              180
#   Pleural effusion          0.2981       0.3632         0.2298            106              101
# Pleural thickening          0.2130       0.2211         0.2025            224              172
#       Pneumothorax          0.4170       0.4112         0.4177              2               18
# Pulmonary fibrosis          0.2238       0.2570         0.1916            159              164
#            Average          0.2891       0.3404         0.2662           1682             1398
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2253       0.2287         0.2102            501              111
#        Atelectasis          0.3389       0.4402         0.3266              4               33
#      Calcification          0.2005       0.5720         0.1963              1               89
#       Cardiomegaly          0.3248       0.3249         0.3244            410               50
#      Consolidation          0.3485       0.4248         0.2525             39               31
#                ILD          0.4434       0.5902         0.4239              9               68
#       Infiltration          0.3190       0.4642         0.2455             41               81
#       Lung Opacity          0.2644       0.3250         0.1808            153              111
#        Nodule/Mass          0.2060       0.2411         0.1975             32              133
#       Other lesion          0.2351       0.3243         0.2021             61              165
#   Pleural effusion          0.2782       0.3488         0.2224             91              115
# Pleural thickening          0.2038       0.2383         0.1846            142              254
#       Pneumothorax          0.4046       0.3902         0.4054              1               18
# Pulmonary fibrosis          0.2151       0.2684         0.1868            112              211
#            Average          0.2863       0.3701         0.2542           1597             1470
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2335       0.2404         0.2136            453              158
#        Atelectasis          0.3682       0.5108         0.3349              7               30
#      Calcification          0.2155       0.4673         0.2099              2               89
#       Cardiomegaly          0.2939       0.2882         0.3247            388               72
#      Consolidation          0.3501       0.4631         0.2764             28               43
#                ILD          0.4941       0.6136         0.4521             20               57
#       Infiltration          0.3111       0.4705         0.2763             22              101
#       Lung Opacity          0.2616       0.3620         0.1925            108              157
#        Nodule/Mass          0.1883       0.0795         0.1903              3              163
#       Other lesion          0.2306       0.3066         0.2057             56              171
#   Pleural effusion          0.2810       0.3510         0.1729            125               81
# Pleural thickening          0.2016       0.2252         0.1671            235              161
#       Pneumothorax          0.4461       0.6411         0.4096              3               16
# Pulmonary fibrosis          0.2272       0.2748         0.1995            119              204
#            Average          0.2931       0.3782         0.2590           1569             1503
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.2316 ± 0.0000
# Correct   : 0.2341 ± 0.0000
# Incorrect : 0.2201 ± 0.0000
#
# Class: Atelectasis
# Proportion: 0.3555 ± 0.0000
# Correct   : 0.4402 ± 0.0000
# Incorrect : 0.3342 ± 0.0000
#
# Class: Calcification
# Proportion: 0.2186 ± 0.0000
# Correct   : 0.4838 ± 0.0000
# Incorrect : 0.2147 ± 0.0000
#
# Class: Cardiomegaly
# Proportion: 0.3031 ± 0.0000
# Correct   : 0.3013 ± 0.0000
# Incorrect : 0.3134 ± 0.0000
#
# Class: Consolidation
# Proportion: 0.3478 ± 0.0000
# Correct   : 0.4481 ± 0.0000
# Incorrect : 0.2759 ± 0.0000
#
# Class: ILD
# Proportion: 0.4686 ± 0.0000
# Correct   : 0.5626 ± 0.0000
# Incorrect : 0.4318 ± 0.0000
#
# Class: Infiltration
# Proportion: 0.3095 ± 0.0000
# Correct   : 0.4385 ± 0.0000
# Incorrect : 0.2530 ± 0.0000
#
# Class: Lung Opacity
# Proportion: 0.2628 ± 0.0000
# Correct   : 0.3466 ± 0.0000
# Incorrect : 0.1881 ± 0.0000
#
# Class: Nodule/Mass
# Proportion: 0.1935 ± 0.0000
# Correct   : 0.1820 ± 0.0000
# Incorrect : 0.1933 ± 0.0000
#
# Class: Other lesion
# Proportion: 0.2298 ± 0.0000
# Correct   : 0.2874 ± 0.0000
# Incorrect : 0.2122 ± 0.0000
#
# Class: Pleural effusion
# Proportion: 0.2890 ± 0.0000
# Correct   : 0.3671 ± 0.0000
# Incorrect : 0.2006 ± 0.0000
#
# Class: Pleural thickening
# Proportion: 0.2070 ± 0.0000
# Correct   : 0.2317 ± 0.0000
# Incorrect : 0.1836 ± 0.0000
#
# Class: Pneumothorax
# Proportion: 0.4162 ± 0.0000
# Correct   : 0.4537 ± 0.0000
# Incorrect : 0.4085 ± 0.0000
#
# Class: Pulmonary fibrosis
# Proportion: 0.2214 ± 0.0000
# Correct   : 0.2611 ± 0.0000
# Incorrect : 0.1881 ± 0.0000
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.2896 ± 0.0000
# Correct   : 0.3599 ± 0.0000
# Incorrect : 0.2584 ± 0.0000

# %%
from libraries_multilabel.energyPointGame import energy_point_game_mask
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID
from pooling.blur_bcosconv2d import ModifiedBcosConv2d


# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"

# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.layer2[0].conv2 = ModifiedBcosConv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2)
        model.layer2[0].downsample[0] = ModifiedBcosConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), b=2)

        model.layer3[0].conv2 = ModifiedBcosConv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2)
        model.layer3[0].downsample[0] = ModifiedBcosConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), b=2)

        model.layer4[0].conv2 = ModifiedBcosConv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2)
        model.layer4[0].downsample[0] = ModifiedBcosConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), b=2)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                            contribution_map[contribution_map < 0] = 0
                            
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_mask(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2033       0.2076         0.1722            537               74
#        Atelectasis          0.4348       0.4414         0.4309             14               24
#      Calcification          0.2268       0.3246         0.2105             13               78
#       Cardiomegaly          0.2954       0.2949         0.2995            409               51
#      Consolidation          0.3871       0.4597         0.3605             19               52
#                ILD          0.4454       0.5532         0.4125             18               59
#       Infiltration          0.3122       0.3551         0.2837             49               74
#       Lung Opacity          0.2633       0.3413         0.1947            124              141
#        Nodule/Mass          0.1624       0.1566         0.1653             55              110
#       Other lesion          0.2403       0.3167         0.2077             68              159
#   Pleural effusion          0.3114       0.3840         0.2366            105              102
# Pleural thickening          0.2003       0.2212         0.1828            181              216
#       Pneumothorax          0.4829       0.5068         0.4801              2               17
# Pulmonary fibrosis          0.2182       0.2305         0.2049            168              156
#            Average          0.2988       0.3424         0.2744           1762             1313
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2096       0.2063         0.2362            544               68
#        Atelectasis          0.3476       0.3986         0.3165             14               23
#      Calcification          0.2153       0.2536         0.2021             23               67
#       Cardiomegaly          0.2955       0.2898         0.3317            398               62
#      Consolidation          0.3807       0.4024         0.3682             26               45
#                ILD          0.4844       0.5940         0.4160             30               48
#       Infiltration          0.2790       0.3970         0.2389             31               91
#       Lung Opacity          0.2603       0.3409         0.1720            138              126
#        Nodule/Mass          0.1819       0.1725         0.1847             38              127
#       Other lesion          0.1881       0.2333         0.1753             50              177
#   Pleural effusion          0.3066       0.3750         0.2031            124               82
# Pleural thickening          0.1862       0.1929         0.1771            228              168
#       Pneumothorax          0.3992       0.3598         0.4065              3               16
# Pulmonary fibrosis          0.1983       0.2264         0.1743            149              175
#            Average          0.2809       0.3173         0.2573           1796             1275
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2189       0.2154         0.2408            536               85
#        Atelectasis          0.3829       0.4184         0.3659             12               25
#      Calcification          0.1951       0.2551         0.1822             16               74
#       Cardiomegaly          0.3158       0.3157         0.3165            407               53
#      Consolidation          0.3755       0.5077         0.2924             27               43
#                ILD          0.4739       0.5624         0.4262             27               50
#       Infiltration          0.2848       0.3962         0.2312             40               83
#       Lung Opacity          0.2606       0.3403         0.1900            124              140
#        Nodule/Mass          0.2034       0.2084         0.2011             50              115
#       Other lesion          0.2259       0.2657         0.2109             62              165
#   Pleural effusion          0.3353       0.3999         0.2306            128               79
# Pleural thickening          0.2041       0.2167         0.1864            232              164
#       Pneumothorax          0.4348       0.5532         0.3840              6               14
# Pulmonary fibrosis          0.2087       0.2249         0.1826            199              124
#            Average          0.2943       0.3486         0.2601           1866             1214
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2238       0.2244         0.2194            536               76
#        Atelectasis          0.3359       0.4293         0.2853             13               24
#      Calcification          0.1994       0.2190         0.1934             21               69
#       Cardiomegaly          0.3372       0.3346         0.3562            404               56
#      Consolidation          0.3605       0.4368         0.3155             26               44
#                ILD          0.4246       0.5400         0.3813             21               56
#       Infiltration          0.3110       0.3768         0.2752             43               79
#       Lung Opacity          0.2490       0.3029         0.2061            117              147
#        Nodule/Mass          0.2052       0.1818         0.2132             42              123
#       Other lesion          0.2271       0.2712         0.2061             73              153
#   Pleural effusion          0.2953       0.3423         0.2297            120               86
# Pleural thickening          0.1999       0.2080         0.1893            225              171
#       Pneumothorax          0.4269       0.5781         0.3729              5               14
# Pulmonary fibrosis          0.2185       0.2339         0.1970            188              135
#            Average          0.2867       0.3342         0.2600           1834             1233
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2273       0.2277         0.2233            555               56
#        Atelectasis          0.3804       0.3527         0.3921             11               26
#      Calcification          0.2120       0.2612         0.1982             20               71
#       Cardiomegaly          0.3231       0.3225         0.3285            413               47
#      Consolidation          0.3997       0.4382         0.3894             15               56
#                ILD          0.4818       0.6141         0.4255             23               54
#       Infiltration          0.3109       0.4135         0.2749             32               91
#       Lung Opacity          0.2570       0.3191         0.2200             99              166
#        Nodule/Mass          0.1823       0.1642         0.1905             52              114
#       Other lesion          0.2476       0.2915         0.2296             66              161
#   Pleural effusion          0.2829       0.3491         0.1719            129               77
# Pleural thickening          0.1990       0.1998         0.1974            257              139
#       Pneumothorax          0.4742       0.6610         0.4244              4               15
# Pulmonary fibrosis          0.2183       0.2183         0.2183            200              123
#            Average          0.2998       0.3452         0.2774           1876             1196
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2225       0.2236         0.2146            537               74
#        Atelectasis          0.4310       0.4591         0.4081             17               21
#      Calcification          0.2251       0.2482         0.1982             49               42
#       Cardiomegaly          0.3372       0.3344         0.3530            391               69
#      Consolidation          0.3763       0.4303         0.3521             22               49
#                ILD          0.4188       0.4810         0.3870             26               51
#       Infiltration          0.3273       0.4537         0.2951             25               98
#       Lung Opacity          0.2454       0.2899         0.1978            137              128
#        Nodule/Mass          0.1732       0.1619         0.1775             45              120
#       Other lesion          0.2501       0.2622         0.2390            109              118
#   Pleural effusion          0.3246       0.4143         0.2358            103              104
# Pleural thickening          0.2102       0.2259         0.1910            218              179
#       Pneumothorax          0.5445       0.6874         0.4934              5               14
# Pulmonary fibrosis          0.2268       0.2836         0.2000            104              220
#            Average          0.3081       0.3540         0.2816           1788             1287
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2245       0.2218         0.2480            550               62
#        Atelectasis          0.3768       0.4288         0.3326             17               20
#      Calcification          0.2400       0.4051         0.2146             12               78
#       Cardiomegaly          0.3101       0.3069         0.3347            406               54
#      Consolidation          0.4279       0.4817         0.3693             37               34
#                ILD          0.5118       0.5531         0.4956             22               56
#       Infiltration          0.3107       0.3861         0.2725             41               81
#       Lung Opacity          0.2826       0.3938         0.2033            110              154
#        Nodule/Mass          0.2033       0.2070         0.2022             38              127
#       Other lesion          0.2204       0.2766         0.2062             46              181
#   Pleural effusion          0.3272       0.3983         0.2197            124               82
# Pleural thickening          0.2112       0.2097         0.2136            244              152
#       Pneumothorax          0.4249       0.5169         0.4076              3               16
# Pulmonary fibrosis          0.2239       0.2438         0.2016            171              153
#            Average          0.3068       0.3593         0.2801           1821             1250
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2342       0.2335         0.2402            558               63
#        Atelectasis          0.3862       0.4349         0.3599             13               24
#      Calcification          0.2167       0.1912         0.2214             14               76
#       Cardiomegaly          0.3265       0.3286         0.3102            408               52
#      Consolidation          0.3988       0.5232         0.3490             20               50
#                ILD          0.5019       0.5666         0.4744             23               54
#       Infiltration          0.3141       0.4199         0.2720             35               88
#       Lung Opacity          0.2781       0.3755         0.2097            109              155
#        Nodule/Mass          0.2216       0.1940         0.2268             26              139
#       Other lesion          0.2425       0.2668         0.2303             76              151
#   Pleural effusion          0.3315       0.3824         0.2437            131               76
# Pleural thickening          0.2189       0.2220         0.2134            255              141
#       Pneumothorax          0.5149       0.5694         0.5012              4               16
# Pulmonary fibrosis          0.2306       0.2518         0.2025            184              139
#            Average          0.3155       0.3543         0.2896           1856             1224
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2153       0.2142         0.2227            531               81
#        Atelectasis          0.3291       0.4624         0.2727             11               26
#      Calcification          0.1846       0.2579         0.1688             16               74
#       Cardiomegaly          0.3087       0.3044         0.3306            386               74
#      Consolidation          0.3748       0.4682         0.3196             26               44
#                ILD          0.4353       0.5131         0.3857             30               47
#       Infiltration          0.3094       0.3792         0.2727             42               80
#       Lung Opacity          0.2486       0.3071         0.1874            135              129
#        Nodule/Mass          0.2029       0.2008         0.2039             52              113
#       Other lesion          0.2238       0.3131         0.1957             54              172
#   Pleural effusion          0.2833       0.3292         0.1979            134               72
# Pleural thickening          0.1903       0.2002         0.1791            209              187
#       Pneumothorax          0.4309       0.4313         0.4308              4               15
# Pulmonary fibrosis          0.2169       0.2348         0.1867            203              120
#            Average          0.2824       0.3297         0.2539           1833             1234
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.2138       0.2149         0.2032            555               56
#        Atelectasis          0.3909       0.4221         0.3777             11               26
#      Calcification          0.2197       0.3048         0.2092             10               81
#       Cardiomegaly          0.2877       0.2801         0.3406            402               58
#      Consolidation          0.3885       0.5240         0.3491             16               55
#                ILD          0.4542       0.5861         0.4079             20               57
#       Infiltration          0.3055       0.4261         0.2613             33               90
#       Lung Opacity          0.2455       0.3184         0.1921            112              153
#        Nodule/Mass          0.1817       0.1567         0.1870             29              137
#       Other lesion          0.2337       0.2873         0.2182             51              176
#   Pleural effusion          0.2776       0.3353         0.1848            127               79
# Pleural thickening          0.1858       0.2081         0.1532            235              161
#       Pneumothorax          0.4841       0.3891         0.4953              2               17
# Pulmonary fibrosis          0.2174       0.2271         0.2073            164              159
#            Average          0.2919       0.3343         0.2705           1767             1305
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.2193 ± 0.0027
# Correct   : 0.2189 ± 0.0027
# Incorrect : 0.2221 ± 0.0037
#
# Class: Atelectasis
# Proportion: 0.3796 ± 0.0032
# Correct   : 0.4248 ± 0.0167
# Incorrect : 0.3542 ± 0.0040
#
# Class: Calcification
# Proportion: 0.2135 ± 0.0038
# Correct   : 0.2721 ± 0.0094
# Incorrect : 0.1999 ± 0.0026
#
# Class: Cardiomegaly
# Proportion: 0.3137 ± 0.0003
# Correct   : 0.3112 ± 0.0003
# Incorrect : 0.3301 ± 0.0037
#
# Class: Consolidation
# Proportion: 0.3870 ± 0.0063
# Correct   : 0.4672 ± 0.0183
# Incorrect : 0.3465 ± 0.0013
#
# Class: ILD
# Proportion: 0.4632 ± 0.0012
# Correct   : 0.5564 ± 0.0164
# Incorrect : 0.4212 ± 0.0089
#
# Class: Infiltration
# Proportion: 0.3065 ± 0.0069
# Correct   : 0.4004 ± 0.0126
# Incorrect : 0.2677 ± 0.0070
#
# Class: Lung Opacity
# Proportion: 0.2590 ± 0.0010
# Correct   : 0.3329 ± 0.0040
# Incorrect : 0.1973 ± 0.0008
#
# Class: Nodule/Mass
# Proportion: 0.1918 ± 0.0048
# Correct   : 0.1804 ± 0.0037
# Incorrect : 0.1952 ± 0.0043
#
# Class: Other lesion
# Proportion: 0.2300 ± 0.0042
# Correct   : 0.2784 ± 0.0028
# Incorrect : 0.2119 ± 0.0060
#
# Class: Pleural effusion
# Proportion: 0.3076 ± 0.0013
# Correct   : 0.3710 ± 0.0009
# Incorrect : 0.2154 ± 0.0010
#
# Class: Pleural thickening
# Proportion: 0.2006 ± 0.0027
# Correct   : 0.2104 ± 0.0027
# Incorrect : 0.1883 ± 0.0017
#
# Class: Pneumothorax
# Proportion: 0.4617 ± 0.0181
# Correct   : 0.5253 ± 0.0065
# Incorrect : 0.4396 ± 0.0260
#
# Class: Pulmonary fibrosis
# Proportion: 0.2178 ± 0.0054
# Correct   : 0.2375 ± 0.0107
# Incorrect : 0.1975 ± 0.0021
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.2965 ± 0.0044
# Correct   : 0.3419 ± 0.0044
# Incorrect : 0.2705 ± 0.0047

# %% [markdown]
# # Recall Calculation
# - Normal FLC

# %%
from libraries_multilabel.energyPointGame import energy_point_game_recall
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID

# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"

# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos\no_nosamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                                                        
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_recall(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9992       0.9999         0.9964            497              114
#        Atelectasis          0.9997       0.9998         0.9996             14               24
#      Calcification          0.9982       0.9998         0.9982              1               90
#       Cardiomegaly          0.9988       0.9999         0.9962            329              131
#      Consolidation          0.9998       0.9998         0.9999             24               47
#                ILD          0.9990       0.9999         0.9988             11               66
#       Infiltration          0.9998       0.9999         0.9997             33               90
#       Lung Opacity          0.9999       0.9998         0.9999            124              141
#        Nodule/Mass          0.9999       0.9998         0.9999             23              142
#       Other lesion          0.9984       0.9997         0.9981             42              185
#   Pleural effusion          0.9998       0.9999         0.9998            136               71
# Pleural thickening          0.9999       0.9999         0.9999            209              188
#       Pneumothorax          0.9993       0.9998         0.9992              4               15
# Pulmonary fibrosis          0.9999       0.9999         0.9999            185              139
#            Average          0.9994       0.9998         0.9990           1632             1443
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            475              137
#        Atelectasis          0.9542       0.9998         0.9453              6               31
#      Calcification          0.9998       0.9997         0.9998             17               73
#       Cardiomegaly          0.9998       0.9998         0.9997            355              105
#      Consolidation          0.9997       0.9998         0.9996             11               60
#                ILD          0.9993       0.9998         0.9992             11               67
#       Infiltration          0.9983       0.9998         0.9978             32               90
#       Lung Opacity          0.9994       0.9997         0.9992            102              162
#        Nodule/Mass          0.9997       0.9997         0.9997             26              139
#       Other lesion          0.9998       0.9997         0.9998             30              197
#   Pleural effusion          0.9998       0.9997         0.9998            118               88
# Pleural thickening          0.9998       0.9998         0.9998            158              238
#       Pneumothorax          0.9976       0.9993         0.9974              2               17
# Pulmonary fibrosis          0.9998       0.9998         0.9998            160              164
#            Average          0.9962       0.9997         0.9955           1503             1568
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            533               88
#        Atelectasis          0.9988       0.9999         0.9983             11               26
#      Calcification          0.9998       0.9996         0.9998              6               84
#       Cardiomegaly          0.9998       0.9998         0.9998            428               32
#      Consolidation          0.9998       0.9998         0.9998             23               47
#                ILD          0.9998       0.9998         0.9998             22               55
#       Infiltration          0.9999       0.9999         0.9998             53               70
#       Lung Opacity          0.9998       0.9998         0.9998            115              149
#        Nodule/Mass          0.9998       0.9997         0.9998             12              153
#       Other lesion          0.9998       0.9997         0.9998             60              167
#   Pleural effusion          0.9998       0.9998         0.9998            102              105
# Pleural thickening          0.9998       0.9998         0.9998            199              197
#       Pneumothorax          0.9955       0.9996         0.9950              2               18
# Pulmonary fibrosis          0.9999       0.9998         0.9999            201              122
#            Average          0.9994       0.9998         0.9994           1767             1313
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9984       0.9998         0.9883            536               76
#        Atelectasis          0.9998       0.9996         0.9998              9               28
#      Calcification          0.9998       0.0000         0.9998              0               90
#       Cardiomegaly          0.9989       0.9999         0.9938            387               73
#      Consolidation          0.9998       0.9997         0.9998             20               50
#                ILD          0.9868       0.9999         0.9855              7               70
#       Infiltration          0.9999       0.9999         0.9999             37               85
#       Lung Opacity          0.9997       0.9998         0.9995            162              102
#        Nodule/Mass          0.9999       0.9999         0.9999             59              106
#       Other lesion          0.9989       0.9998         0.9988             17              209
#   Pleural effusion          0.9998       0.9998         0.9998            145               61
# Pleural thickening          0.9998       0.9998         0.9998            252              144
#       Pneumothorax          0.9551       0.9994         0.9468              3               16
# Pulmonary fibrosis          0.9967       0.9999         0.9934            166              157
#            Average          0.9952       0.9284         0.9932           1800             1267
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            538               73
#        Atelectasis          0.9641       0.9999         0.9509             10               27
#      Calcification          0.9998       0.9998         0.9998              5               86
#       Cardiomegaly          0.9998       0.9998         0.9997            353              107
#      Consolidation          0.9946       0.9998         0.9931             16               55
#                ILD          0.9995       0.9998         0.9994             16               61
#       Infiltration          0.9996       0.9999         0.9995             37               86
#       Lung Opacity          0.9998       0.9998         0.9998             88              177
#        Nodule/Mass          0.9998       0.9998         0.9998             19              147
#       Other lesion          0.9996       0.9997         0.9996             30              197
#   Pleural effusion          0.9998       0.9998         0.9998             93              113
# Pleural thickening          0.9998       0.9998         0.9998            211              185
#       Pneumothorax          0.9979       0.9999         0.9975              3               16
# Pulmonary fibrosis          0.9997       0.9999         0.9997            132              191
#            Average          0.9967       0.9998         0.9956           1551             1521
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9989       0.9998         0.9926            535               76
#        Atelectasis          0.9980       0.9995         0.9962             20               18
#      Calcification          0.9996       0.9995         0.9996             11               80
#       Cardiomegaly          0.9996       0.9998         0.9988            373               87
#      Consolidation          0.9995       0.9996         0.9995             28               43
#                ILD          0.9975       0.9998         0.9970             15               62
#       Infiltration          0.9984       0.9998         0.9979             36               87
#       Lung Opacity          0.9996       0.9996         0.9995             81              184
#        Nodule/Mass          0.9998       0.9998         0.9998             34              131
#       Other lesion          0.9996       0.9996         0.9996             94              133
#   Pleural effusion          0.9982       0.9997         0.9962            116               91
# Pleural thickening          0.9987       0.9997         0.9980            172              225
#       Pneumothorax          0.9725       0.9984         0.9656              4               15
# Pulmonary fibrosis          0.9996       0.9997         0.9995            115              209
#            Average          0.9971       0.9996         0.9957           1634             1441
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9993       0.9997         0.9968            509              103
#        Atelectasis          0.9457       0.9998         0.9391              4               33
#      Calcification          0.9907       0.9998         0.9902              5               85
#       Cardiomegaly          0.9975       0.9998         0.9908            345              115
#      Consolidation          0.9995       0.9997         0.9995             22               49
#                ILD          0.9898       0.9994         0.9887              8               70
#       Infiltration          0.9911       0.9999         0.9890             24               98
#       Lung Opacity          0.9955       0.9997         0.9919            120              144
#        Nodule/Mass          0.9997       0.9997         0.9997             39              126
#       Other lesion          0.9997       0.9997         0.9998            160               67
#   Pleural effusion          0.9994       0.9997         0.9990            115               91
# Pleural thickening          0.9998       0.9998         0.9998            165              231
#       Pneumothorax          0.9985       0.9992         0.9983              3               16
# Pulmonary fibrosis          0.9967       0.9998         0.9929            176              148
#            Average          0.9931       0.9997         0.9911           1695             1376
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9997       0.9997         0.9998            479              142
#        Atelectasis          0.9978       0.9997         0.9971             10               27
#      Calcification          0.9997       0.9996         0.9998             24               66
#       Cardiomegaly          0.9997       0.9997         0.9997            370               90
#      Consolidation          0.9996       0.9995         0.9996             17               53
#                ILD          0.9996       0.9997         0.9996             29               48
#       Infiltration          0.9997       0.9998         0.9997             39               84
#       Lung Opacity          0.9995       0.9996         0.9995             62              202
#        Nodule/Mass          0.9997       0.9997         0.9997             30              135
#       Other lesion          0.9996       0.9996         0.9997             55              172
#   Pleural effusion          0.9948       0.9996         0.9868            129               78
# Pleural thickening          0.9997       0.9997         0.9998            249              147
#       Pneumothorax          0.9469       0.0000         0.9469              0               20
# Pulmonary fibrosis          0.9997       0.9998         0.9996            159              164
#            Average          0.9954       0.9283         0.9948           1652             1428
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            443              169
#        Atelectasis          0.9998       0.9998         0.9998             15               22
#      Calcification          0.9998       0.9998         0.9998             10               80
#       Cardiomegaly          0.9998       0.9998         0.9997            271              189
#      Consolidation          0.9998       0.9998         0.9998             40               30
#                ILD          0.9999       0.9999         0.9999             18               59
#       Infiltration          0.9999       0.9999         0.9998             75               47
#       Lung Opacity          0.9998       0.9998         0.9998            143              121
#        Nodule/Mass          0.9998       0.9998         0.9998             63              102
#       Other lesion          0.9998       0.9996         0.9998             73              153
#   Pleural effusion          0.9998       0.9998         0.9998            154               52
# Pleural thickening          0.9998       0.9998         0.9998            331               65
#       Pneumothorax          0.9997       0.9997         0.9997              5               14
# Pulmonary fibrosis          0.9999       0.9999         0.9999            214              109
#            Average          0.9998       0.9998         0.9998           1855             1212
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       0.9999         0.9999            507              104
#        Atelectasis          0.9728       0.9999         0.9563             14               23
#      Calcification          0.9999       0.9997         0.9999              3               88
#       Cardiomegaly          0.9999       1.0000         0.9999            342              118
#      Consolidation          0.9998       0.9998         0.9999             29               42
#                ILD          0.9998       0.9999         0.9997             33               44
#       Infiltration          0.9999       0.9999         0.9999             75               48
#       Lung Opacity          0.9999       0.9999         0.9999            143              122
#        Nodule/Mass          0.9999       0.9999         0.9999             36              130
#       Other lesion          0.9999       0.9999         0.9999             29              198
#   Pleural effusion          0.9999       0.9999         0.9999            151               55
# Pleural thickening          0.9999       0.9999         0.9999            300               96
#       Pneumothorax          0.9992       0.9995         0.9992              2               17
# Pulmonary fibrosis          0.9998       0.9999         0.9995            265               58
#            Average          0.9979       0.9999         0.9967           1929             1143
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.9995 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9973 ± 0.0005
#
# Class: Atelectasis
# Proportion: 0.9831 ± 0.0002
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9782 ± 0.0005
#
# Class: Calcification
# Proportion: 0.9987 ± 0.0008
# Correct   : 0.8997 ± 0.0999
# Incorrect : 0.9987 ± 0.0008
#
# Class: Cardiomegaly
# Proportion: 0.9994 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9978 ± 0.0000
#
# Class: Consolidation
# Proportion: 0.9992 ± 0.0005
# Correct   : 0.9997 ± 0.0001
# Incorrect : 0.9990 ± 0.0006
#
# Class: ILD
# Proportion: 0.9971 ± 0.0002
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9968 ± 0.0002
#
# Class: Infiltration
# Proportion: 0.9987 ± 0.0008
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9983 ± 0.0010
#
# Class: Lung Opacity
# Proportion: 0.9993 ± 0.0004
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9989 ± 0.0008
#
# Class: Nodule/Mass
# Proportion: 0.9998 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9998 ± 0.0000
#
# Class: Other lesion
# Proportion: 0.9995 ± 0.0002
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9995 ± 0.0003
#
# Class: Pleural effusion
# Proportion: 0.9991 ± 0.0007
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9981 ± 0.0017
#
# Class: Pleural thickening
# Proportion: 0.9997 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9996 ± 0.0002
#
# Class: Pneumothorax
# Proportion: 0.9862 ± 0.0029
# Correct   : 0.8995 ± 0.1001
# Incorrect : 0.9846 ± 0.0026
#
# Class: Pulmonary fibrosis
# Proportion: 0.9992 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9984 ± 0.0001
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.9970 ± 0.0004
# Correct   : 0.9855 ± 0.0000
# Incorrect : 0.9961 ± 0.0005

# %%
from libraries_multilabel.energyPointGame import energy_point_game_recall
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID

# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"

# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos\light_oversamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                                                        
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_recall(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          1.0000       1.0000         0.9999            555               56
#        Atelectasis          0.9991       0.9999         0.9987             15               23
#      Calcification          0.9998       0.9996         0.9999             15               76
#       Cardiomegaly          1.0000       1.0000         1.0000            412               48
#      Consolidation          0.9999       0.9999         0.9998             25               46
#                ILD          0.9998       1.0000         0.9997             17               60
#       Infiltration          0.9998       1.0000         0.9998             47               76
#       Lung Opacity          0.9999       0.9999         0.9999            104              161
#        Nodule/Mass          1.0000       0.9999         1.0000             47              118
#       Other lesion          0.9999       0.9999         0.9999             50              177
#   Pleural effusion          0.9999       0.9999         0.9999            117               90
# Pleural thickening          0.9999       0.9999         0.9999            194              203
#       Pneumothorax          0.9997       0.9997         0.9997              4               15
# Pulmonary fibrosis          0.9999       0.9999         0.9999            162              162
#            Average          0.9998       0.9999         0.9998           1764             1311
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       1.0000         0.9997            548               64
#        Atelectasis          0.9960       0.9999         0.9939             13               24
#      Calcification          1.0000       0.9999         1.0000             24               66
#       Cardiomegaly          1.0000       1.0000         1.0000            415               45
#      Consolidation          0.9999       0.9999         0.9999             23               48
#                ILD          0.9999       0.9999         0.9999             23               55
#       Infiltration          0.9999       1.0000         0.9998             41               81
#       Lung Opacity          0.9999       0.9999         0.9999            125              139
#        Nodule/Mass          0.9999       0.9999         0.9999             43              122
#       Other lesion          0.9999       0.9999         0.9999             75              152
#   Pleural effusion          0.9997       0.9999         0.9993            133               73
# Pleural thickening          0.9999       0.9999         0.9999            226              170
#       Pneumothorax          0.9988       0.9997         0.9986              4               15
# Pulmonary fibrosis          0.9999       0.9999         0.9999            159              165
#            Average          0.9995       0.9999         0.9993           1852             1219
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          1.0000       1.0000         0.9999            542               79
#        Atelectasis          0.9999       0.9999         0.9999              9               28
#      Calcification          0.9999       0.9999         1.0000             13               77
#       Cardiomegaly          1.0000       1.0000         0.9999            412               48
#      Consolidation          0.9866       0.9998         0.9835             13               57
#                ILD          0.9999       0.9999         0.9999             19               58
#       Infiltration          0.9999       0.9999         0.9999             35               88
#       Lung Opacity          0.9999       0.9999         0.9999            102              162
#        Nodule/Mass          0.9999       0.9999         1.0000             32              133
#       Other lesion          0.9999       0.9999         0.9999             47              180
#   Pleural effusion          0.9999       0.9999         0.9999            129               78
# Pleural thickening          0.9999       0.9999         1.0000            193              203
#       Pneumothorax          0.9814       0.9999         0.9768              4               16
# Pulmonary fibrosis          0.9999       0.9999         1.0000            165              158
#            Average          0.9976       0.9999         0.9971           1715             1365
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          1.0000       1.0000         1.0000            534               78
#        Atelectasis          0.9971       1.0000         0.9961              9               28
#      Calcification          1.0000       1.0000         0.9999             13               77
#       Cardiomegaly          1.0000       1.0000         0.9999            386               74
#      Consolidation          0.9999       0.9999         0.9999             22               48
#                ILD          1.0000       0.9999         1.0000             19               58
#       Infiltration          1.0000       1.0000         0.9999             41               81
#       Lung Opacity          0.9999       0.9999         1.0000            118              146
#        Nodule/Mass          0.9999       1.0000         0.9999             38              127
#       Other lesion          0.9999       0.9999         0.9999             60              166
#   Pleural effusion          0.9999       0.9999         0.9998            125               81
# Pleural thickening          1.0000       1.0000         1.0000            187              209
#       Pneumothorax          0.9452       0.9999         0.9133              7               12
# Pulmonary fibrosis          1.0000       1.0000         0.9999            151              172
#            Average          0.9958       1.0000         0.9935           1710             1357
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          1.0000       1.0000         0.9999            551               60
#        Atelectasis          0.9999       0.9999         0.9999             10               27
#      Calcification          0.9999       0.9999         0.9999             20               71
#       Cardiomegaly          0.9999       1.0000         0.9998            401               59
#      Consolidation          0.9986       0.9997         0.9982             18               53
#                ILD          0.9999       0.9999         0.9999             21               56
#       Infiltration          0.9999       1.0000         0.9999             39               84
#       Lung Opacity          0.9999       0.9999         0.9999            118              147
#        Nodule/Mass          0.9999       0.9999         0.9999             44              122
#       Other lesion          0.9999       0.9999         0.9999             42              185
#   Pleural effusion          0.9999       0.9999         0.9999            118               88
# Pleural thickening          0.9999       0.9999         0.9999            204              192
#       Pneumothorax          0.9918       0.9995         0.9909              2               17
# Pulmonary fibrosis          0.9999       0.9999         0.9999            150              173
#            Average          0.9992       0.9999         0.9991           1738             1334
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          1.0000       1.0000         0.9999            538               73
#        Atelectasis          0.9997       0.9999         0.9996             15               23
#      Calcification          0.9999       0.9999         0.9999             10               81
#       Cardiomegaly          1.0000       1.0000         1.0000            354              106
#      Consolidation          0.9999       0.9999         0.9999             18               53
#                ILD          0.9999       0.9999         0.9999             25               52
#       Infiltration          0.9999       0.9999         1.0000             54               69
#       Lung Opacity          0.9999       0.9999         0.9999            125              140
#        Nodule/Mass          1.0000       1.0000         1.0000             27              138
#       Other lesion          0.9999       0.9999         0.9999             69              158
#   Pleural effusion          0.9999       0.9999         0.9999            112               95
# Pleural thickening          0.9999       0.9999         1.0000            218              179
#       Pneumothorax          0.9996       0.9999         0.9996              3               16
# Pulmonary fibrosis          0.9999       0.9999         0.9999            270               54
#            Average          0.9999       0.9999         0.9999           1838             1237
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       1.0000         0.9998            545               67
#        Atelectasis          1.0000       0.9999         1.0000             16               21
#      Calcification          1.0000       0.9999         1.0000             18               72
#       Cardiomegaly          1.0000       1.0000         0.9999            369               91
#      Consolidation          0.9999       0.9999         0.9999             36               35
#                ILD          0.9999       0.9999         1.0000             28               50
#       Infiltration          0.9998       1.0000         0.9997             41               81
#       Lung Opacity          0.9999       0.9999         0.9999            130              134
#        Nodule/Mass          0.9999       1.0000         0.9999             43              122
#       Other lesion          0.9999       0.9999         1.0000            138               89
#   Pleural effusion          0.9999       0.9999         0.9998            137               69
# Pleural thickening          0.9999       0.9999         0.9999            275              121
#       Pneumothorax          0.9998       0.9999         0.9998              5               14
# Pulmonary fibrosis          0.9999       1.0000         0.9999            133              191
#            Average          0.9999       0.9999         0.9999           1914             1157
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          1.0000       1.0000         1.0000            548               73
#        Atelectasis          0.9915       1.0000         0.9883             10               27
#      Calcification          1.0000       0.9999         1.0000              8               82
#       Cardiomegaly          1.0000       1.0000         1.0000            414               46
#      Consolidation          0.9985       0.9999         0.9980             20               50
#                ILD          0.9999       0.9999         0.9999             28               49
#       Infiltration          0.9999       0.9999         0.9998             46               77
#       Lung Opacity          0.9999       0.9999         1.0000            123              141
#        Nodule/Mass          1.0000       1.0000         1.0000             37              128
#       Other lesion          1.0000       0.9999         1.0000             60              167
#   Pleural effusion          0.9999       0.9999         0.9997            133               74
# Pleural thickening          1.0000       1.0000         1.0000            240              156
#       Pneumothorax          0.9990       0.9999         0.9987              4               16
# Pulmonary fibrosis          1.0000       1.0000         1.0000            200              123
#            Average          0.9992       0.9999         0.9989           1871             1209
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          1.0000       1.0000         1.0000            542               70
#        Atelectasis          0.9999       0.9999         1.0000             10               27
#      Calcification          1.0000       1.0000         1.0000             12               78
#       Cardiomegaly          1.0000       1.0000         1.0000            385               75
#      Consolidation          0.9998       0.9999         0.9998             22               48
#                ILD          1.0000       0.9999         1.0000             29               48
#       Infiltration          0.9999       1.0000         0.9999             49               73
#       Lung Opacity          1.0000       0.9999         1.0000            128              136
#        Nodule/Mass          1.0000       1.0000         0.9999             41              124
#       Other lesion          1.0000       0.9999         1.0000             56              170
#   Pleural effusion          0.9999       0.9999         0.9999            124               82
# Pleural thickening          1.0000       1.0000         1.0000            210              186
#       Pneumothorax          0.9325       0.9999         0.9199              3               16
# Pulmonary fibrosis          1.0000       1.0000         1.0000            168              155
#            Average          0.9951       1.0000         0.9942           1779             1288
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       0.9999         0.9999            559               52
#        Atelectasis          0.9996       0.9999         0.9995              7               30
#      Calcification          0.9999       0.9998         0.9999             15               76
#       Cardiomegaly          0.9999       0.9999         0.9994            406               54
#      Consolidation          0.9985       0.9996         0.9981             15               56
#                ILD          0.9999       0.9998         0.9999             20               57
#       Infiltration          0.9999       0.9999         0.9999             35               88
#       Lung Opacity          0.9999       0.9999         0.9999            113              152
#        Nodule/Mass          0.9998       0.9999         0.9997             41              125
#       Other lesion          0.9999       0.9999         0.9999             50              177
#   Pleural effusion          0.9999       0.9999         0.9999            116               90
# Pleural thickening          0.9999       0.9999         0.9999            225              171
#       Pneumothorax          0.9791       0.9999         0.9752              3               16
# Pulmonary fibrosis          0.9999       0.9999         0.9999            159              164
#            Average          0.9983       0.9999         0.9979           1764             1308
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 1.0000 ± 0.0000
# Correct   : 1.0000 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# Class: Atelectasis
# Proportion: 0.9983 ± 0.0001
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9976 ± 0.0001
#
# Class: Calcification
# Proportion: 0.9999 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 1.0000 ± 0.0000
#
# Class: Cardiomegaly
# Proportion: 1.0000 ± 0.0000
# Correct   : 1.0000 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# Class: Consolidation
# Proportion: 0.9981 ± 0.0012
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9977 ± 0.0014
#
# Class: ILD
# Proportion: 0.9999 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# Class: Infiltration
# Proportion: 0.9999 ± 0.0000
# Correct   : 1.0000 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# Class: Lung Opacity
# Proportion: 0.9999 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# Class: Nodule/Mass
# Proportion: 0.9999 ± 0.0000
# Correct   : 1.0000 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# Class: Other lesion
# Proportion: 0.9999 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# Class: Pleural effusion
# Proportion: 0.9999 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9998 ± 0.0000
#
# Class: Pleural thickening
# Proportion: 0.9999 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 1.0000 ± 0.0000
#
# Class: Pneumothorax
# Proportion: 0.9827 ± 0.0007
# Correct   : 0.9998 ± 0.0001
# Incorrect : 0.9772 ± 0.0014
#
# Class: Pulmonary fibrosis
# Proportion: 0.9999 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9999 ± 0.0000
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.9984 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9980 ± 0.0002

# %%
from libraries_multilabel.energyPointGame import energy_point_game_recall
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID
from pooling.flc_bcosconv2d import ModifiedFLCBcosConv2d

# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"


# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.layer2[0].conv2 = ModifiedFLCBcosConv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2, transpose=True)
        model.layer2[0].downsample[0] = ModifiedFLCBcosConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), b=2, transpose=False)

        model.layer3[0].conv2 = ModifiedFLCBcosConv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2, transpose=True)
        model.layer3[0].downsample[0] = ModifiedFLCBcosConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), b=2, transpose=False)

        model.layer4[0].conv2 = ModifiedFLCBcosConv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2, transpose=True)
        model.layer4[0].downsample[0] = ModifiedFLCBcosConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), b=2, transpose=False)    

        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                                                        
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_recall(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9999         0.9997            514               97
#        Atelectasis          0.9996       0.9998         0.9995             15               23
#      Calcification          0.9997       0.9997         0.9997              1               90
#       Cardiomegaly          0.9998       0.9998         0.9998            300              160
#      Consolidation          0.9998       0.9998         0.9999             35               36
#                ILD          0.9998       0.9999         0.9997             38               39
#       Infiltration          0.9999       0.9999         0.9998             64               59
#       Lung Opacity          0.9998       0.9998         0.9998            126              139
#        Nodule/Mass          0.9999       0.9999         0.9999              5              160
#       Other lesion          0.9989       0.9998         0.9987             43              184
#   Pleural effusion          0.9995       0.9998         0.9991            115               92
# Pleural thickening          0.9998       0.9998         0.9998            192              205
#       Pneumothorax          0.9958       0.9999         0.9956              1               18
# Pulmonary fibrosis          0.9999       0.9999         0.9999            181              143
#            Average          0.9994       0.9998         0.9994           1630             1445
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9950       0.9997         0.9837            430              182
#        Atelectasis          0.9542       0.9998         0.9373             10               27
#      Calcification          0.9884       0.9992         0.9881              2               88
#       Cardiomegaly          0.9958       0.9998         0.9818            358              102
#      Consolidation          0.9990       0.9996         0.9986             26               45
#                ILD          0.9973       0.9999         0.9967             15               63
#       Infiltration          0.9757       0.9998         0.9652             37               85
#       Lung Opacity          0.9870       0.9998         0.9735            136              128
#        Nodule/Mass          0.9991       0.9997         0.9990             31              134
#       Other lesion          0.9965       0.9998         0.9957             45              182
#   Pleural effusion          0.9934       0.9997         0.9868            106              100
# Pleural thickening          0.9975       0.9998         0.9953            189              207
#       Pneumothorax          0.9994       0.9992         0.9995              4               15
# Pulmonary fibrosis          0.9916       0.9999         0.9818            175              149
#            Average          0.9907       0.9997         0.9845           1564             1507
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9992       0.9999         0.9944            544               77
#        Atelectasis          0.9984       0.9999         0.9979              8               29
#      Calcification          0.9999       1.0000         0.9999              3               87
#       Cardiomegaly          0.9999       0.9999         0.9996            397               63
#      Consolidation          0.9998       0.9999         0.9998             19               51
#                ILD          0.9985       0.9999         0.9980             19               58
#       Infiltration          0.9993       0.9999         0.9991             31               92
#       Lung Opacity          0.9994       0.9999         0.9990            104              160
#        Nodule/Mass          0.9999       0.9999         0.9999             19              146
#       Other lesion          0.9966       0.9999         0.9957             47              180
#   Pleural effusion          0.9997       0.9998         0.9995            106              101
# Pleural thickening          0.9999       0.9999         0.9998            224              172
#       Pneumothorax          0.9998       0.9998         0.9998              2               18
# Pulmonary fibrosis          0.9988       0.9999         0.9976            159              164
#            Average          0.9992       0.9999         0.9986           1682             1398
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9997       0.9997         0.9996            501              111
#        Atelectasis          0.9969       0.9994         0.9966              4               33
#      Calcification          0.9996       0.9997         0.9996              1               89
#       Cardiomegaly          0.9993       0.9997         0.9956            410               50
#      Consolidation          0.9961       0.9995         0.9920             39               31
#                ILD          0.9997       0.9998         0.9997              9               68
#       Infiltration          0.9994       0.9997         0.9992             41               81
#       Lung Opacity          0.9942       0.9996         0.9868            153              111
#        Nodule/Mass          0.9986       0.9998         0.9984             32              133
#       Other lesion          0.9969       0.9996         0.9958             61              165
#   Pleural effusion          0.9979       0.9996         0.9965             91              115
# Pleural thickening          0.9985       0.9997         0.9978            142              254
#       Pneumothorax          0.9619       0.9995         0.9598              1               18
# Pulmonary fibrosis          0.9993       0.9998         0.9990            112              211
#            Average          0.9956       0.9997         0.9940           1597             1470
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9965       0.9992         0.9887            453              158
#        Atelectasis          0.9918       0.9997         0.9899              7               30
#      Calcification          0.9859       0.9994         0.9855              2               89
#       Cardiomegaly          0.9969       0.9995         0.9833            388               72
#      Consolidation          0.9994       0.9997         0.9992             28               43
#                ILD          0.9960       0.9994         0.9948             20               57
#       Infiltration          0.9988       0.9998         0.9986             22              101
#       Lung Opacity          0.9984       0.9996         0.9976            108              157
#        Nodule/Mass          0.9982       0.9998         0.9982              3              163
#       Other lesion          0.9975       0.9993         0.9969             56              171
#   Pleural effusion          0.9954       0.9994         0.9893            125               81
# Pleural thickening          0.9974       0.9994         0.9945            235              161
#       Pneumothorax          0.9989       0.9989         0.9989              3               16
# Pulmonary fibrosis          0.9974       0.9995         0.9961            119              204
#            Average          0.9963       0.9995         0.9937           1569             1503
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9999         0.9997            514               97
#        Atelectasis          0.9996       0.9998         0.9995             15               23
#      Calcification          0.9997       0.9997         0.9997              1               90
#       Cardiomegaly          0.9998       0.9998         0.9998            300              160
#      Consolidation          0.9998       0.9998         0.9999             35               36
#                ILD          0.9998       0.9999         0.9997             38               39
#       Infiltration          0.9999       0.9999         0.9998             64               59
#       Lung Opacity          0.9998       0.9998         0.9998            126              139
#        Nodule/Mass          0.9999       0.9999         0.9999              5              160
#       Other lesion          0.9989       0.9998         0.9987             43              184
#   Pleural effusion          0.9995       0.9998         0.9991            115               92
# Pleural thickening          0.9998       0.9998         0.9998            192              205
#       Pneumothorax          0.9958       0.9999         0.9956              1               18
# Pulmonary fibrosis          0.9999       0.9999         0.9999            181              143
#            Average          0.9994       0.9998         0.9994           1630             1445
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9950       0.9997         0.9837            430              182
#        Atelectasis          0.9542       0.9998         0.9373             10               27
#      Calcification          0.9884       0.9992         0.9881              2               88
#       Cardiomegaly          0.9958       0.9998         0.9818            358              102
#      Consolidation          0.9990       0.9996         0.9986             26               45
#                ILD          0.9973       0.9999         0.9967             15               63
#       Infiltration          0.9757       0.9998         0.9652             37               85
#       Lung Opacity          0.9870       0.9998         0.9735            136              128
#        Nodule/Mass          0.9991       0.9997         0.9990             31              134
#       Other lesion          0.9965       0.9998         0.9957             45              182
#   Pleural effusion          0.9934       0.9997         0.9868            106              100
# Pleural thickening          0.9975       0.9998         0.9953            189              207
#       Pneumothorax          0.9994       0.9992         0.9995              4               15
# Pulmonary fibrosis          0.9916       0.9999         0.9818            175              149
#            Average          0.9907       0.9997         0.9845           1564             1507
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9992       0.9999         0.9944            544               77
#        Atelectasis          0.9984       0.9999         0.9979              8               29
#      Calcification          0.9999       1.0000         0.9999              3               87
#       Cardiomegaly          0.9999       0.9999         0.9996            397               63
#      Consolidation          0.9998       0.9999         0.9998             19               51
#                ILD          0.9985       0.9999         0.9980             19               58
#       Infiltration          0.9993       0.9999         0.9991             31               92
#       Lung Opacity          0.9994       0.9999         0.9990            104              160
#        Nodule/Mass          0.9999       0.9999         0.9999             19              146
#       Other lesion          0.9966       0.9999         0.9957             47              180
#   Pleural effusion          0.9997       0.9998         0.9995            106              101
# Pleural thickening          0.9999       0.9999         0.9998            224              172
#       Pneumothorax          0.9998       0.9998         0.9998              2               18
# Pulmonary fibrosis          0.9988       0.9999         0.9976            159              164
#            Average          0.9992       0.9999         0.9986           1682             1398
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9997       0.9997         0.9996            501              111
#        Atelectasis          0.9969       0.9994         0.9966              4               33
#      Calcification          0.9996       0.9997         0.9996              1               89
#       Cardiomegaly          0.9993       0.9997         0.9956            410               50
#      Consolidation          0.9961       0.9995         0.9920             39               31
#                ILD          0.9997       0.9998         0.9997              9               68
#       Infiltration          0.9994       0.9997         0.9992             41               81
#       Lung Opacity          0.9942       0.9996         0.9868            153              111
#        Nodule/Mass          0.9986       0.9998         0.9984             32              133
#       Other lesion          0.9969       0.9996         0.9958             61              165
#   Pleural effusion          0.9979       0.9996         0.9965             91              115
# Pleural thickening          0.9985       0.9997         0.9978            142              254
#       Pneumothorax          0.9619       0.9995         0.9598              1               18
# Pulmonary fibrosis          0.9993       0.9998         0.9990            112              211
#            Average          0.9956       0.9997         0.9940           1597             1470
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9965       0.9992         0.9887            453              158
#        Atelectasis          0.9918       0.9997         0.9899              7               30
#      Calcification          0.9859       0.9994         0.9855              2               89
#       Cardiomegaly          0.9969       0.9995         0.9833            388               72
#      Consolidation          0.9994       0.9997         0.9992             28               43
#                ILD          0.9960       0.9994         0.9948             20               57
#       Infiltration          0.9988       0.9998         0.9986             22              101
#       Lung Opacity          0.9984       0.9996         0.9976            108              157
#        Nodule/Mass          0.9982       0.9998         0.9982              3              163
#       Other lesion          0.9975       0.9993         0.9969             56              171
#   Pleural effusion          0.9954       0.9994         0.9893            125               81
# Pleural thickening          0.9974       0.9994         0.9945            235              161
#       Pneumothorax          0.9989       0.9989         0.9989              3               16
# Pulmonary fibrosis          0.9974       0.9995         0.9961            119              204
#            Average          0.9963       0.9995         0.9937           1569             1503
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.9980 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9932 ± 0.0000
#
# Class: Atelectasis
# Proportion: 0.9882 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9842 ± 0.0000
#
# Class: Calcification
# Proportion: 0.9947 ± 0.0000
# Correct   : 0.9996 ± 0.0000
# Incorrect : 0.9946 ± 0.0000
#
# Class: Cardiomegaly
# Proportion: 0.9983 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9920 ± 0.0000
#
# Class: Consolidation
# Proportion: 0.9988 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9979 ± 0.0000
#
# Class: ILD
# Proportion: 0.9983 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9978 ± 0.0000
#
# Class: Infiltration
# Proportion: 0.9946 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9924 ± 0.0000
#
# Class: Lung Opacity
# Proportion: 0.9958 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9913 ± 0.0000
#
# Class: Nodule/Mass
# Proportion: 0.9991 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9991 ± 0.0000
#
# Class: Other lesion
# Proportion: 0.9973 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9966 ± 0.0000
#
# Class: Pleural effusion
# Proportion: 0.9972 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9942 ± 0.0000
#
# Class: Pleural thickening
# Proportion: 0.9986 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9974 ± 0.0000
#
# Class: Pneumothorax
# Proportion: 0.9912 ± 0.0000
# Correct   : 0.9995 ± 0.0000
# Incorrect : 0.9907 ± 0.0000
#
# Class: Pulmonary fibrosis
# Proportion: 0.9974 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9949 ± 0.0000
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.9962 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9940 ± 0.0000

# %%
from libraries_multilabel.energyPointGame import energy_point_game_recall
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID

# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"

# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos\no_nosamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                                                        
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_recall(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9992       0.9999         0.9964            497              114
#        Atelectasis          0.9997       0.9998         0.9996             14               24
#      Calcification          0.9982       0.9998         0.9982              1               90
#       Cardiomegaly          0.9988       0.9999         0.9962            329              131
#      Consolidation          0.9998       0.9998         0.9999             24               47
#                ILD          0.9990       0.9999         0.9988             11               66
#       Infiltration          0.9998       0.9999         0.9997             33               90
#       Lung Opacity          0.9999       0.9998         0.9999            124              141
#        Nodule/Mass          0.9999       0.9998         0.9999             23              142
#       Other lesion          0.9984       0.9997         0.9981             42              185
#   Pleural effusion          0.9998       0.9999         0.9998            136               71
# Pleural thickening          0.9999       0.9999         0.9999            209              188
#       Pneumothorax          0.9993       0.9998         0.9992              4               15
# Pulmonary fibrosis          0.9999       0.9999         0.9999            185              139
#            Average          0.9994       0.9998         0.9990           1632             1443
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            475              137
#        Atelectasis          0.9542       0.9998         0.9453              6               31
#      Calcification          0.9998       0.9997         0.9998             17               73
#       Cardiomegaly          0.9998       0.9998         0.9997            355              105
#      Consolidation          0.9997       0.9998         0.9996             11               60
#                ILD          0.9993       0.9998         0.9992             11               67
#       Infiltration          0.9983       0.9998         0.9978             32               90
#       Lung Opacity          0.9994       0.9997         0.9992            102              162
#        Nodule/Mass          0.9997       0.9997         0.9997             26              139
#       Other lesion          0.9998       0.9997         0.9998             30              197
#   Pleural effusion          0.9998       0.9997         0.9998            118               88
# Pleural thickening          0.9998       0.9998         0.9998            158              238
#       Pneumothorax          0.9976       0.9993         0.9974              2               17
# Pulmonary fibrosis          0.9998       0.9998         0.9998            160              164
#            Average          0.9962       0.9997         0.9955           1503             1568
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            533               88
#        Atelectasis          0.9988       0.9999         0.9983             11               26
#      Calcification          0.9998       0.9996         0.9998              6               84
#       Cardiomegaly          0.9998       0.9998         0.9998            428               32
#      Consolidation          0.9998       0.9998         0.9998             23               47
#                ILD          0.9998       0.9998         0.9998             22               55
#       Infiltration          0.9999       0.9999         0.9998             53               70
#       Lung Opacity          0.9998       0.9998         0.9998            115              149
#        Nodule/Mass          0.9998       0.9997         0.9998             12              153
#       Other lesion          0.9998       0.9997         0.9998             60              167
#   Pleural effusion          0.9998       0.9998         0.9998            102              105
# Pleural thickening          0.9998       0.9998         0.9998            199              197
#       Pneumothorax          0.9955       0.9996         0.9950              2               18
# Pulmonary fibrosis          0.9999       0.9998         0.9999            201              122
#            Average          0.9994       0.9998         0.9994           1767             1313
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9984       0.9998         0.9883            536               76
#        Atelectasis          0.9998       0.9996         0.9998              9               28
#      Calcification          0.9998       0.0000         0.9998              0               90
#       Cardiomegaly          0.9989       0.9999         0.9938            387               73
#      Consolidation          0.9998       0.9997         0.9998             20               50
#                ILD          0.9868       0.9999         0.9855              7               70
#       Infiltration          0.9999       0.9999         0.9999             37               85
#       Lung Opacity          0.9997       0.9998         0.9995            162              102
#        Nodule/Mass          0.9999       0.9999         0.9999             59              106
#       Other lesion          0.9989       0.9998         0.9988             17              209
#   Pleural effusion          0.9998       0.9998         0.9998            145               61
# Pleural thickening          0.9998       0.9998         0.9998            252              144
#       Pneumothorax          0.9551       0.9994         0.9468              3               16
# Pulmonary fibrosis          0.9967       0.9999         0.9934            166              157
#            Average          0.9952       0.9284         0.9932           1800             1267
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            538               73
#        Atelectasis          0.9641       0.9999         0.9509             10               27
#      Calcification          0.9998       0.9998         0.9998              5               86
#       Cardiomegaly          0.9998       0.9998         0.9997            353              107
#      Consolidation          0.9946       0.9998         0.9931             16               55
#                ILD          0.9995       0.9998         0.9994             16               61
#       Infiltration          0.9996       0.9999         0.9995             37               86
#       Lung Opacity          0.9998       0.9998         0.9998             88              177
#        Nodule/Mass          0.9998       0.9998         0.9998             19              147
#       Other lesion          0.9996       0.9997         0.9996             30              197
#   Pleural effusion          0.9998       0.9998         0.9998             93              113
# Pleural thickening          0.9998       0.9998         0.9998            211              185
#       Pneumothorax          0.9979       0.9999         0.9975              3               16
# Pulmonary fibrosis          0.9997       0.9999         0.9997            132              191
#            Average          0.9967       0.9998         0.9956           1551             1521
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9989       0.9998         0.9926            535               76
#        Atelectasis          0.9980       0.9995         0.9962             20               18
#      Calcification          0.9996       0.9995         0.9996             11               80
#       Cardiomegaly          0.9996       0.9998         0.9988            373               87
#      Consolidation          0.9995       0.9996         0.9995             28               43
#                ILD          0.9975       0.9998         0.9970             15               62
#       Infiltration          0.9984       0.9998         0.9979             36               87
#       Lung Opacity          0.9996       0.9996         0.9995             81              184
#        Nodule/Mass          0.9998       0.9998         0.9998             34              131
#       Other lesion          0.9996       0.9996         0.9996             94              133
#   Pleural effusion          0.9982       0.9997         0.9962            116               91
# Pleural thickening          0.9987       0.9997         0.9980            172              225
#       Pneumothorax          0.9725       0.9984         0.9656              4               15
# Pulmonary fibrosis          0.9996       0.9997         0.9995            115              209
#            Average          0.9971       0.9996         0.9957           1634             1441
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9993       0.9997         0.9968            509              103
#        Atelectasis          0.9457       0.9998         0.9391              4               33
#      Calcification          0.9907       0.9998         0.9902              5               85
#       Cardiomegaly          0.9975       0.9998         0.9908            345              115
#      Consolidation          0.9995       0.9997         0.9995             22               49
#                ILD          0.9898       0.9994         0.9887              8               70
#       Infiltration          0.9911       0.9999         0.9890             24               98
#       Lung Opacity          0.9955       0.9997         0.9919            120              144
#        Nodule/Mass          0.9997       0.9997         0.9997             39              126
#       Other lesion          0.9997       0.9997         0.9998            160               67
#   Pleural effusion          0.9994       0.9997         0.9990            115               91
# Pleural thickening          0.9998       0.9998         0.9998            165              231
#       Pneumothorax          0.9985       0.9992         0.9983              3               16
# Pulmonary fibrosis          0.9967       0.9998         0.9929            176              148
#            Average          0.9931       0.9997         0.9911           1695             1376
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9997       0.9997         0.9998            479              142
#        Atelectasis          0.9978       0.9997         0.9971             10               27
#      Calcification          0.9997       0.9996         0.9998             24               66
#       Cardiomegaly          0.9997       0.9997         0.9997            370               90
#      Consolidation          0.9996       0.9995         0.9996             17               53
#                ILD          0.9996       0.9997         0.9996             29               48
#       Infiltration          0.9997       0.9998         0.9997             39               84
#       Lung Opacity          0.9995       0.9996         0.9995             62              202
#        Nodule/Mass          0.9997       0.9997         0.9997             30              135
#       Other lesion          0.9996       0.9996         0.9997             55              172
#   Pleural effusion          0.9948       0.9996         0.9868            129               78
# Pleural thickening          0.9997       0.9997         0.9998            249              147
#       Pneumothorax          0.9469       0.0000         0.9469              0               20
# Pulmonary fibrosis          0.9997       0.9998         0.9996            159              164
#            Average          0.9954       0.9283         0.9948           1652             1428
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            443              169
#        Atelectasis          0.9998       0.9998         0.9998             15               22
#      Calcification          0.9998       0.9998         0.9998             10               80
#       Cardiomegaly          0.9998       0.9998         0.9997            271              189
#      Consolidation          0.9998       0.9998         0.9998             40               30
#                ILD          0.9999       0.9999         0.9999             18               59
#       Infiltration          0.9999       0.9999         0.9998             75               47
#       Lung Opacity          0.9998       0.9998         0.9998            143              121
#        Nodule/Mass          0.9998       0.9998         0.9998             63              102
#       Other lesion          0.9998       0.9996         0.9998             73              153
#   Pleural effusion          0.9998       0.9998         0.9998            154               52
# Pleural thickening          0.9998       0.9998         0.9998            331               65
#       Pneumothorax          0.9997       0.9997         0.9997              5               14
# Pulmonary fibrosis          0.9999       0.9999         0.9999            214              109
#            Average          0.9998       0.9998         0.9998           1855             1212
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       0.9999         0.9999            507              104
#        Atelectasis          0.9728       0.9999         0.9563             14               23
#      Calcification          0.9999       0.9997         0.9999              3               88
#       Cardiomegaly          0.9999       1.0000         0.9999            342              118
#      Consolidation          0.9998       0.9998         0.9999             29               42
#                ILD          0.9998       0.9999         0.9997             33               44
#       Infiltration          0.9999       0.9999         0.9999             75               48
#       Lung Opacity          0.9999       0.9999         0.9999            143              122
#        Nodule/Mass          0.9999       0.9999         0.9999             36              130
#       Other lesion          0.9999       0.9999         0.9999             29              198
#   Pleural effusion          0.9999       0.9999         0.9999            151               55
# Pleural thickening          0.9999       0.9999         0.9999            300               96
#       Pneumothorax          0.9992       0.9995         0.9992              2               17
# Pulmonary fibrosis          0.9998       0.9999         0.9995            265               58
#            Average          0.9979       0.9999         0.9967           1929             1143
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.9995 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9973 ± 0.0005
#
# Class: Atelectasis
# Proportion: 0.9831 ± 0.0002
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9782 ± 0.0005
#
# Class: Calcification
# Proportion: 0.9987 ± 0.0008
# Correct   : 0.8997 ± 0.0999
# Incorrect : 0.9987 ± 0.0008
#
# Class: Cardiomegaly
# Proportion: 0.9994 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9978 ± 0.0000
#
# Class: Consolidation
# Proportion: 0.9992 ± 0.0005
# Correct   : 0.9997 ± 0.0001
# Incorrect : 0.9990 ± 0.0006
#
# Class: ILD
# Proportion: 0.9971 ± 0.0002
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9968 ± 0.0002
#
# Class: Infiltration
# Proportion: 0.9987 ± 0.0008
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9983 ± 0.0010
#
# Class: Lung Opacity
# Proportion: 0.9993 ± 0.0004
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9989 ± 0.0008
#
# Class: Nodule/Mass
# Proportion: 0.9998 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9998 ± 0.0000
#
# Class: Other lesion
# Proportion: 0.9995 ± 0.0002
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9995 ± 0.0003
#
# Class: Pleural effusion
# Proportion: 0.9991 ± 0.0007
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9981 ± 0.0017
#
# Class: Pleural thickening
# Proportion: 0.9997 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9996 ± 0.0002
#
# Class: Pneumothorax
# Proportion: 0.9862 ± 0.0029
# Correct   : 0.8995 ± 0.1001
# Incorrect : 0.9846 ± 0.0026
#
# Class: Pulmonary fibrosis
# Proportion: 0.9992 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9984 ± 0.0001
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.9970 ± 0.0004
# Correct   : 0.9855 ± 0.0000
# Incorrect : 0.9961 ± 0.0005

# %%
from libraries_multilabel.energyPointGame import energy_point_game_recall
from libraries_multilabel.bcosconv2d import NormedConv2d

import random
import numpy as np
import torch
import pandas as pd
import os
from PIL import Image
import pickle
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from libraries_multilabel.bcoslinear import BcosLinear
from libraries_multilabel.MultiLabelExplanationWrapper import MultiLabelModelWrapper
from libraries_multilabel.MultiLabelDatasets import MultiLabelDatasetID
from pooling.blur_bcosconv2d import ModifiedBcosConv2d


# Configuration
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path configurations
image_folder = r"D:\vinbigdata-chest-xray-abnormalities-detection\train_png_224"
csv_path_boxes = r"D:\vinbigdata-chest-xray-abnormalities-detection\train224.csv"
csv_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\multilabel_dataset.csv"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Multi-Classification\training\vinbigdata_5fold_splits.pkl"


# Initialize datasets and transforms
data = pd.read_csv(csv_path)
data_boxes = pd.read_csv(csv_path_boxes)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    
transform = transforms.Compose([transforms.ToTensor()])
class_names = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis"]

class_names_extended = ["Aortic enlargement", "Atelectasis", "Calcification", "Cardiomegaly",
    "Consolidation", "ILD", "Infiltration", "Lung Opacity",
    "Nodule/Mass", "Other lesion", "Pleural effusion", "Pleural thickening",
    "Pneumothorax", "Pulmonary fibrosis", "Average"]

seeds = [0, 1]
seed_results = {
    name: {
        'proportions': [],
        'correct': [],
        'incorrect': [],
    } for name in class_names
}

seed_results_avg = { 
        'proportions': [],
        'correct': [],
        'incorrect': []
        }

for seed in seeds:
    print(f"\n=== Seed {seed+1} Results ===")
    all_fold_results = []
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    fold_average_results = {name: {
            'avg_proportion': [],
            'avg_correct': [],
            'avg_incorrect': [],
            'correct_count': [],
            'incorrect_count': []
        } for name in class_names}

    fold_avg_row_results = {'proportions': [],
        'correct': [],
        'incorrect': []
        }

    # Process all 5 folds
    for fold in range(5):
        print(f"Processing fold {fold+1} of 5")
        model_path = fr"C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_{seed}\pneumonia_detection_model_resnet_bcos_bestf1_{fold+1}.pth"
        
        # Initialize results storage        
        fold_all_outputs = {name: {
            'proportions': [],
            'correct': [],
            'incorrect': [],
            'correct_count': 0,
            'incorrect_count': 0
        } for name in class_names} # need to be averaged for final_fold_result


        model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
        model.fc.linear = NormedConv2d(2048, 14, kernel_size=(1, 1), bias=False)
        model.layer2[0].conv2 = ModifiedBcosConv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2)
        model.layer2[0].downsample[0] = ModifiedBcosConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), b=2)

        model.layer3[0].conv2 = ModifiedBcosConv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2)
        model.layer3[0].downsample[0] = ModifiedBcosConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), b=2)

        model.layer4[0].conv2 = ModifiedBcosConv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), b=2)
        model.layer4[0].downsample[0] = ModifiedBcosConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), b=2)

        model.load_state_dict(torch.load(model_path))
        model.to(device)

        
        val_idx = splits[fold][1]
        val_data = data.iloc[val_idx]
        val_dataset = MultiLabelDatasetID(val_data, image_folder, transform=transform)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

        multiLabelWrapper = MultiLabelModelWrapper(model)
        model.eval()
        multiLabelWrapper.model.eval()

        with torch.enable_grad():
            for images, labels, image_ids in val_loader:
                labels = labels.to(device)
                six_channel_images = []
                
                # Convert images to 6-channel format
                for img_tensor in images:
                    numpy_image = (img_tensor.permute(1, 2, 0).cpu().numpy() * 255).astype(np.uint8)
                    pil_image = Image.fromarray(numpy_image)
                    transformed_image = model.transform(pil_image)
                    six_channel_images.append(transformed_image)
                
                six_channel_images = torch.stack(six_channel_images).to(device)
                
                mask = torch.zeros((224, 224), dtype=torch.int32)
                for image, label, image_id in zip(six_channel_images, labels, image_ids):
                    image = image[None]  # Add batch dimension
                    expl = multiLabelWrapper.explain(image)
                    
                    # Process each class
                    for class_idx, class_name in enumerate(class_names):
                        filtered_rows = data_boxes[(data_boxes['image_id'] == image_id)]
                        labels_row = data[data['image_id'] == image_id]
                        
                        if not filtered_rows.empty and not labels_row.empty and labels_row[class_name].iloc[0] == 1:
                            prediction = expl["binary_predictions"][0][class_idx]
                            contribution_map = expl['contribution_maps'][class_idx]
                                                        
                            # Create mask from bounding boxes
                            mask.zero_()
                            for _, row in filtered_rows.iterrows():
                                x_min = int(row["x_min"])
                                y_min = int(row["y_min"])
                                x_max = int(row["x_max"])
                                y_max = int(row["y_max"])
                                mask[y_min:y_max, x_min:x_max] = 1.0
                            
                            # Calculate energy point game metric
                            ebpg_result = energy_point_game_recall(mask.cpu(), contribution_map.cpu())
                            
                            # Update results
                            fold_all_outputs[class_name]['proportions'].append(ebpg_result)
                            if prediction == 1:
                                fold_all_outputs[class_name]['correct'].append(ebpg_result)
                                fold_all_outputs[class_name]['correct_count'] += 1
                            else:
                                fold_all_outputs[class_name]['incorrect'].append(ebpg_result)
                                fold_all_outputs[class_name]['incorrect_count'] += 1
                                
                        
        for class_name in class_names:
            class_fold_result = fold_all_outputs[class_name]
            
            avg_total = np.mean(class_fold_result['proportions']) if class_fold_result['proportions'] else 0
            avg_correct = np.mean(class_fold_result['correct']) if class_fold_result['correct'] else 0
            avg_incorrect = np.mean(class_fold_result['incorrect']) if class_fold_result['incorrect'] else 0
            
            fold_average_results[class_name]['avg_proportion'].append(round(avg_total, 4))
            fold_average_results[class_name]['avg_correct'].append(round(avg_correct, 4))
            fold_average_results[class_name]['avg_incorrect'].append(round(avg_incorrect, 4))
            fold_average_results[class_name]['correct_count'].append(class_fold_result['correct_count'])
            fold_average_results[class_name]['incorrect_count'].append(class_fold_result['incorrect_count'])

        rows = []
        for class_name in class_names:
            rows.append({
                'Class': class_name,
                'avg_proportion': fold_average_results[class_name]['avg_proportion'][fold],
                'avg_correct': fold_average_results[class_name]['avg_correct'][fold],
                'avg_incorrect': fold_average_results[class_name]['avg_incorrect'][fold],
                'correct_count': fold_average_results[class_name]['correct_count'][fold],
                'incorrect_count': fold_average_results[class_name]['incorrect_count'][fold]
            })

        df = pd.DataFrame(rows)

        # add an average row
        avg_row = {
            'Class': 'Average',
            'avg_proportion': round(df['avg_proportion'].mean(), 4),
            'avg_correct': round(df['avg_correct'].mean(), 4),
            'avg_incorrect': round(df['avg_incorrect'].mean(), 4),
            'correct_count': int(df['correct_count'].sum()),        
            'incorrect_count': int(df['incorrect_count'].sum()),    
        }
        fold_avg_row_results['proportions'].append(avg_row['avg_proportion'])
        fold_avg_row_results['correct'].append(avg_row['avg_correct'])
        fold_avg_row_results['incorrect'].append(avg_row['avg_incorrect'])

        
        df = pd.concat([
            df,
            pd.DataFrame([avg_row])  # Wrap in list to create 1-row DataFrame
        ], ignore_index=True)

        print(f"\nEnergy-Based Pointing Game Results for Fold {fold+1}:")
        print(df.to_string(index=False))        
        
        if fold == 4:
            for class_name in class_names:
                seed_results[class_name]['proportions'].append(np.mean(fold_average_results[class_name]['avg_proportion']))
                seed_results[class_name]['correct'].append(np.mean(fold_average_results[class_name]['avg_correct']))
                seed_results[class_name]['incorrect'].append(np.mean(fold_average_results[class_name]['avg_incorrect']))   
                
            seed_results_avg['proportions'].append(np.mean(fold_avg_row_results['proportions']))
            seed_results_avg['correct'].append(np.mean(fold_avg_row_results['correct']))
            seed_results_avg['incorrect'].append(np.mean(fold_avg_row_results['incorrect']))

                
        
                    

def calculate_stats(values):
    return f"{np.mean(values):.4f} ± {np.std(values):.4f}"

all_props = []
all_corrs = []
all_incorrects = []

print("\n\n=== Final Cross-Seed Averages ===")
for class_name in class_names:
    print(f"\nClass: {class_name}")
    print("Proportion:", calculate_stats(seed_results[class_name]['proportions']))
    print("Correct   :", calculate_stats(seed_results[class_name]['correct']))
    print("Incorrect :", calculate_stats(seed_results[class_name]['incorrect']))

print("\n=== Final Cross-Seed Average (across all classes) ===")
print("Proportion:", calculate_stats(seed_results_avg['proportions']))
print("Correct   :", calculate_stats(seed_results_avg['correct']))
print("Incorrect :", calculate_stats(seed_results_avg['incorrect']))
# Out:
# === Seed 1 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9999         0.9998            537               74
#        Atelectasis          0.9812       0.9996         0.9705             14               24
#      Calcification          0.9993       0.9990         0.9994             13               78
#       Cardiomegaly          0.9996       0.9997         0.9987            409               51
#      Consolidation          0.9986       0.9996         0.9982             19               52
#                ILD          0.9989       0.9999         0.9986             18               59
#       Infiltration          0.9970       0.9999         0.9951             49               74
#       Lung Opacity          0.9998       0.9997         0.9998            124              141
#        Nodule/Mass          0.9984       0.9997         0.9978             55              110
#       Other lesion          0.9997       0.9997         0.9998             68              159
#   Pleural effusion          0.9997       0.9996         0.9997            105              102
# Pleural thickening          0.9997       0.9998         0.9996            181              216
#       Pneumothorax          0.9957       0.9998         0.9952              2               17
# Pulmonary fibrosis          0.9998       0.9998         0.9998            168              156
#            Average          0.9977       0.9997         0.9966           1762             1313
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       0.9999         0.9998            544               68
#        Atelectasis          0.9800       0.9998         0.9680             14               23
#      Calcification          0.9998       0.9997         0.9999             23               67
#       Cardiomegaly          0.9999       0.9999         0.9998            398               62
#      Consolidation          0.9998       0.9998         0.9998             26               45
#                ILD          0.9997       0.9997         0.9996             30               48
#       Infiltration          0.9998       0.9999         0.9998             31               91
#       Lung Opacity          0.9998       0.9998         0.9998            138              126
#        Nodule/Mass          0.9998       0.9997         0.9998             38              127
#       Other lesion          0.9993       0.9998         0.9992             50              177
#   Pleural effusion          0.9996       0.9998         0.9992            124               82
# Pleural thickening          0.9998       0.9998         0.9998            228              168
#       Pneumothorax          0.9990       0.9997         0.9989              3               16
# Pulmonary fibrosis          0.9998       0.9998         0.9998            149              175
#            Average          0.9983       0.9998         0.9974           1796             1275
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       0.9999         0.9999            536               85
#        Atelectasis          0.9960       0.9998         0.9942             12               25
#      Calcification          0.9998       0.9998         0.9998             16               74
#       Cardiomegaly          0.9997       0.9999         0.9986            407               53
#      Consolidation          0.9990       0.9997         0.9986             27               43
#                ILD          0.9996       0.9999         0.9995             27               50
#       Infiltration          0.9998       0.9999         0.9998             40               83
#       Lung Opacity          0.9998       0.9998         0.9998            124              140
#        Nodule/Mass          0.9998       0.9998         0.9999             50              115
#       Other lesion          0.9997       0.9998         0.9997             62              165
#   Pleural effusion          0.9998       0.9998         0.9998            128               79
# Pleural thickening          0.9999       0.9998         0.9999            232              164
#       Pneumothorax          0.9442       0.9996         0.9205              6               14
# Pulmonary fibrosis          0.9998       0.9998         0.9998            199              124
#            Average          0.9955       0.9998         0.9936           1866             1214
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9996            536               76
#        Atelectasis          0.9694       0.9995         0.9532             13               24
#      Calcification          0.9958       0.9996         0.9947             21               69
#       Cardiomegaly          0.9998       0.9998         0.9996            404               56
#      Consolidation          0.9970       0.9994         0.9956             26               44
#                ILD          0.9996       0.9994         0.9997             21               56
#       Infiltration          0.9996       0.9998         0.9996             43               79
#       Lung Opacity          0.9997       0.9995         0.9998            117              147
#        Nodule/Mass          0.9996       0.9996         0.9996             42              123
#       Other lesion          0.9996       0.9996         0.9996             73              153
#   Pleural effusion          0.9986       0.9995         0.9973            120               86
# Pleural thickening          0.9997       0.9997         0.9997            225              171
#       Pneumothorax          0.9359       0.9994         0.9133              5               14
# Pulmonary fibrosis          0.9997       0.9997         0.9997            188              135
#            Average          0.9924       0.9996         0.9894           1834             1233
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       0.9999         0.9998            555               56
#        Atelectasis          0.9827       0.9999         0.9754             11               26
#      Calcification          0.9987       0.9994         0.9986             20               71
#       Cardiomegaly          0.9999       0.9999         0.9999            413               47
#      Consolidation          0.9993       0.9996         0.9992             15               56
#                ILD          0.9998       0.9996         0.9999             23               54
#       Infiltration          0.9998       0.9999         0.9998             32               91
#       Lung Opacity          0.9998       0.9998         0.9998             99              166
#        Nodule/Mass          0.9998       0.9998         0.9997             52              114
#       Other lesion          0.9998       0.9997         0.9998             66              161
#   Pleural effusion          0.9998       0.9998         0.9998            129               77
# Pleural thickening          0.9998       0.9998         0.9999            257              139
#       Pneumothorax          0.9950       0.9999         0.9938              4               15
# Pulmonary fibrosis          0.9998       0.9998         0.9998            200              123
#            Average          0.9981       0.9998         0.9975           1876             1196
#
# === Seed 2 Results ===
# Processing fold 1 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 1:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9999         0.9989            537               74
#        Atelectasis          0.9990       0.9997         0.9984             17               21
#      Calcification          0.9996       0.9995         0.9998             49               42
#       Cardiomegaly          0.9995       0.9998         0.9973            391               69
#      Consolidation          0.9708       0.9998         0.9578             22               49
#                ILD          0.9944       0.9998         0.9916             26               51
#       Infiltration          0.9831       0.9999         0.9789             25               98
#       Lung Opacity          0.9997       0.9998         0.9997            137              128
#        Nodule/Mass          0.9993       0.9999         0.9990             45              120
#       Other lesion          0.9998       0.9997         0.9998            109              118
#   Pleural effusion          0.9955       0.9996         0.9914            103              104
# Pleural thickening          0.9998       0.9998         0.9998            218              179
#       Pneumothorax          0.9240       0.9987         0.8973              5               14
# Pulmonary fibrosis          0.9993       0.9997         0.9991            104              220
#            Average          0.9903       0.9997         0.9863           1788             1287
# Processing fold 2 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 2:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            550               62
#        Atelectasis          0.9803       0.9998         0.9637             17               20
#      Calcification          0.9997       0.9995         0.9997             12               78
#       Cardiomegaly          0.9995       0.9998         0.9971            406               54
#      Consolidation          0.9967       0.9996         0.9935             37               34
#                ILD          0.9979       0.9997         0.9972             22               56
#       Infiltration          0.9998       0.9998         0.9998             41               81
#       Lung Opacity          0.9997       0.9997         0.9998            110              154
#        Nodule/Mass          0.9996       0.9998         0.9995             38              127
#       Other lesion          0.9997       0.9997         0.9997             46              181
#   Pleural effusion          0.9993       0.9993         0.9994            124               82
# Pleural thickening          0.9998       0.9998         0.9998            244              152
#       Pneumothorax          0.9591       0.9996         0.9515              3               16
# Pulmonary fibrosis          0.9998       0.9998         0.9997            171              153
#            Average          0.9951       0.9997         0.9929           1821             1250
# Processing fold 3 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 3:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9999       0.9999         0.9998            558               63
#        Atelectasis          0.9977       0.9997         0.9965             13               24
#      Calcification          0.9985       0.9998         0.9983             14               76
#       Cardiomegaly          0.9997       0.9999         0.9981            408               52
#      Consolidation          0.9753       0.9996         0.9656             20               50
#                ILD          0.9941       0.9998         0.9917             23               54
#       Infiltration          0.9987       0.9998         0.9983             35               88
#       Lung Opacity          0.9998       0.9997         0.9998            109              155
#        Nodule/Mass          0.9996       0.9999         0.9996             26              139
#       Other lesion          0.9998       0.9997         0.9998             76              151
#   Pleural effusion          0.9963       0.9997         0.9905            131               76
# Pleural thickening          0.9998       0.9998         0.9998            255              141
#       Pneumothorax          0.9410       0.9996         0.9264              4               16
# Pulmonary fibrosis          0.9997       0.9998         0.9996            184              139
#            Average          0.9929       0.9998         0.9903           1856             1224
# Processing fold 4 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 4:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            531               81
#        Atelectasis          0.9599       0.9994         0.9432             11               26
#      Calcification          0.9994       0.9996         0.9994             16               74
#       Cardiomegaly          0.9995       0.9998         0.9980            386               74
#      Consolidation          0.9979       0.9995         0.9969             26               44
#                ILD          0.9987       0.9996         0.9982             30               47
#       Infiltration          0.9998       0.9999         0.9997             42               80
#       Lung Opacity          0.9998       0.9997         0.9999            135              129
#        Nodule/Mass          0.9998       0.9998         0.9997             52              113
#       Other lesion          0.9997       0.9997         0.9997             54              172
#   Pleural effusion          0.9997       0.9997         0.9996            134               72
# Pleural thickening          0.9998       0.9998         0.9998            209              187
#       Pneumothorax          0.9584       0.9997         0.9473              4               15
# Pulmonary fibrosis          0.9998       0.9998         0.9998            203              120
#            Average          0.9937       0.9997         0.9915           1833             1234
# Processing fold 5 of 5
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# g:\Meine Ablage\Universität\Master Thesis\Multi-Classification\evaluation\libraries_multilabel\MultiLabelExplanationWrapper.py:43: UserWarning: Input tensor did not require grad! Has been set automatically to True!
#   warnings.warn(
# Energy-Based Pointing Game Results for Fold 5:
#              Class  avg_proportion  avg_correct  avg_incorrect  correct_count  incorrect_count
# Aortic enlargement          0.9998       0.9998         0.9998            555               56
#        Atelectasis          0.9669       0.9996         0.9530             11               26
#      Calcification          0.9958       0.9991         0.9954             10               81
#       Cardiomegaly          0.9997       0.9998         0.9996            402               58
#      Consolidation          0.9961       0.9995         0.9951             16               55
#                ILD          0.9934       0.9996         0.9912             20               57
#       Infiltration          0.9993       0.9998         0.9991             33               90
#       Lung Opacity          0.9993       0.9996         0.9990            112              153
#        Nodule/Mass          0.9996       0.9997         0.9995             29              137
#       Other lesion          0.9995       0.9994         0.9995             51              176
#   Pleural effusion          0.9995       0.9995         0.9995            127               79
# Pleural thickening          0.9997       0.9997         0.9998            235              161
#       Pneumothorax          0.9357       0.9998         0.9282              2               17
# Pulmonary fibrosis          0.9997       0.9997         0.9997            164              159
#            Average          0.9917       0.9996         0.9899           1767             1305
#
#
# === Final Cross-Seed Averages ===
#
# Class: Aortic enlargement
# Proportion: 0.9998 ± 0.0000
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9997 ± 0.0001
#
# Class: Atelectasis
# Proportion: 0.9813 ± 0.0006
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9716 ± 0.0006
#
# Class: Calcification
# Proportion: 0.9986 ± 0.0000
# Correct   : 0.9995 ± 0.0000
# Incorrect : 0.9985 ± 0.0000
#
# Class: Cardiomegaly
# Proportion: 0.9997 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9987 ± 0.0006
#
# Class: Consolidation
# Proportion: 0.9930 ± 0.0057
# Correct   : 0.9996 ± 0.0000
# Incorrect : 0.9900 ± 0.0082
#
# Class: ILD
# Proportion: 0.9976 ± 0.0019
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9967 ± 0.0027
#
# Class: Infiltration
# Proportion: 0.9977 ± 0.0015
# Correct   : 0.9999 ± 0.0000
# Incorrect : 0.9970 ± 0.0018
#
# Class: Lung Opacity
# Proportion: 0.9997 ± 0.0001
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9997 ± 0.0001
#
# Class: Nodule/Mass
# Proportion: 0.9995 ± 0.0000
# Correct   : 0.9998 ± 0.0001
# Incorrect : 0.9994 ± 0.0000
#
# Class: Other lesion
# Proportion: 0.9997 ± 0.0000
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9997 ± 0.0000
#
# Class: Pleural effusion
# Proportion: 0.9988 ± 0.0007
# Correct   : 0.9996 ± 0.0001
# Incorrect : 0.9976 ± 0.0015
#
# Class: Pleural thickening
# Proportion: 0.9998 ± 0.0000
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9998 ± 0.0000
#
# Class: Pneumothorax
# Proportion: 0.9588 ± 0.0152
# Correct   : 0.9996 ± 0.0001
# Incorrect : 0.9472 ± 0.0171
#
# Class: Pulmonary fibrosis
# Proportion: 0.9997 ± 0.0001
# Correct   : 0.9998 ± 0.0000
# Incorrect : 0.9997 ± 0.0001
#
# === Final Cross-Seed Average (across all classes) ===
# Proportion: 0.9946 ± 0.0018
# Correct   : 0.9997 ± 0.0000
# Incorrect : 0.9925 ± 0.0024
