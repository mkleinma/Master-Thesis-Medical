# %%
import json
from pathlib import Path
import numpy as np

base_path = Path(r"C:\Users\Admin\Documents\MasterThesis\results\Pneumonia\ResNet50_FLC\no_nosamp")
seed_averages = []

for seed in [0, 1]:
    seed_specificities = []
    
    for fold in range(1, 6):  # Folds 1-5
        file_path = base_path / f"seed_{seed}" / "confusion_matrix" / f"confusion_matrix_best_f1_{fold}.json"
        
        try:
            with open(file_path, 'r') as f:
                data = json.load(f)
                cm = data['confusion_matrix']
                
                # Calculate specificity: TN / (TN + FP)
                tn, fp = cm[0][0], cm[0][1]
                specificity = tn / (tn + fp)
                seed_specificities.append(specificity)
                print(specificity)
                
        except FileNotFoundError:
            print(f"Missing file: {file_path}")
            continue
    
    if seed_specificities:
        seed_avg = np.mean(seed_specificities)
        seed_averages.append(seed_avg)

# Calculate final statistics
mean_spec = np.mean(seed_averages)
std_spec = np.std(seed_averages, ddof=1)  # Sample standard deviation

print(f"Specificity: {mean_spec:.3f} ± {std_spec:.3f}")
# Out:
# 0.8788391777509069
# 0.8164449818621523
# 0.8502660861151428
# 0.8282535074987906
# 0.9029995162070634
# 0.8892382103990326
# 0.8800483675937122
# 0.9032414126753749
# 0.874455732946299
# 0.7866473149492017
# Specificity: 0.861 ± 0.008

# %%
import json
from pathlib import Path
import numpy as np

base_path = Path(r"C:\Users\Admin\Documents\MasterThesis\results\Pneumonia\ResNet50_Blur\light_oversamp")
seed_averages = []

for seed in [0, 1]:
    seed_specificities = []
    
    for fold in range(1, 6):  # Folds 1-5
        file_path = base_path / f"seed_{seed}" / "confusion_matrix" / f"confusion_matrix_best_recall_{fold}.json"
        
        try:
            with open(file_path, 'r') as f:
                data = json.load(f)
                cm = data['confusion_matrix']
                
                # Calculate specificity: TN / (TN + FP)
                tn, fp = cm[0][0], cm[0][1]
                specificity = tn / (tn + fp)
                seed_specificities.append(specificity)
                print(specificity)
                
        except FileNotFoundError:
            print(f"Missing file: {file_path}")
            continue
    
    if seed_specificities:
        seed_avg = np.mean(seed_specificities)
        seed_averages.append(seed_avg)

# Calculate final statistics
mean_spec = np.mean(seed_averages)
std_spec = np.std(seed_averages, ddof=1)  # Sample standard deviation

print(f"Specificity: {mean_spec:.3f} ± {std_spec:.3f}")
# Out:
# 0.5042321644498187
# 0.6858524788391778
# 0.4760522496371553
# 0.658200290275762
# 0.6470730527334301
# 0.5293833131801693
# 0.6781136638452236
# 0.6373971940009676
# 0.5948234155781326
# 0.6686018384131591
# Specificity: 0.608 ± 0.019

# %%
import json
from pathlib import Path
import numpy as np

base_path = Path(r"C:/Users/Admin/Documents/MasterThesis/results/VinBigData/ResNet_Bcos_FLC/no_nosamp")
all_seed_fold_specificities = []

for seed in [0, 1]:
    print(f"\nProcessing seed {seed}")
    seed_specificities = []
    for fold in range(1, 6):
        file_path = base_path / f"seed_{seed}" / "confusion_matrix" / f"confusion_matrix_best_f1_{fold}.json"
        print(f"  Fold {fold}: {file_path}")
        try:
            with open(file_path, 'r') as f:
                data = json.load(f)
                confusion_matrices = data["confusion_matrices"]
                per_label_specificities = []
                for idx, cm in enumerate(confusion_matrices):
                    tn = cm[0][0]
                    fp = cm[0][1]
                    denom = tn + fp
                    specificity = tn / denom if denom != 0 else float('nan')
                    per_label_specificities.append(specificity)
                    print(f"    Label {idx}: TN={tn}, FP={fp}, Specificity={specificity:.4f}")
                fold_avg = np.nanmean(per_label_specificities)
                print(f"  Fold {fold} average specificity: {fold_avg:.4f}")
                seed_specificities.append(fold_avg)
        except FileNotFoundError:
            print(f"    File not found: {file_path}")
            continue
    if seed_specificities:
        seed_avg = np.nanmean(seed_specificities)
        print(f"Seed {seed} average specificity across folds: {seed_avg:.4f}")
        all_seed_fold_specificities.append(seed_avg)
    else:
        print(f"  No valid folds for seed {seed}")

if all_seed_fold_specificities:
    mean_spec = np.nanmean(all_seed_fold_specificities)
    std_spec = np.nanstd(all_seed_fold_specificities, ddof=1) if len(all_seed_fold_specificities) > 1 else 0.0
    print(f"\nFinal result: Specificity = {mean_spec:.4f} ± {std_spec:.4f}")
else:
    print("\nNo specificity values could be calculated because all files are missing.")
# Out:
# Processing seed 0
#   Fold 1: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_0\confusion_matrix\confusion_matrix_best_f1_1.json
#     Label 0: TN=2282, FP=107, Specificity=0.9552
#     Label 1: TN=2954, FP=8, Specificity=0.9973
#     Label 2: TN=2908, FP=1, Specificity=0.9997
#     Label 3: TN=2514, FP=26, Specificity=0.9898
#     Label 4: TN=2866, FP=63, Specificity=0.9785
#     Label 5: TN=2827, FP=96, Specificity=0.9672
#     Label 6: TN=2775, FP=102, Specificity=0.9645
#     Label 7: TN=2652, FP=83, Specificity=0.9697
#     Label 8: TN=2829, FP=6, Specificity=0.9979
#     Label 9: TN=2718, FP=55, Specificity=0.9802
#     Label 10: TN=2745, FP=48, Specificity=0.9828
#     Label 11: TN=2491, FP=112, Specificity=0.9570
#     Label 12: TN=2981, FP=0, Specificity=1.0000
#     Label 13: TN=2522, FP=154, Specificity=0.9425
#   Fold 1 average specificity: 0.9773
#   Fold 2: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_0\confusion_matrix\confusion_matrix_best_f1_2.json
#     Label 0: TN=2329, FP=59, Specificity=0.9753
#     Label 1: TN=2945, FP=18, Specificity=0.9939
#     Label 2: TN=2899, FP=11, Specificity=0.9962
#     Label 3: TN=2464, FP=76, Specificity=0.9701
#     Label 4: TN=2905, FP=24, Specificity=0.9918
#     Label 5: TN=2909, FP=13, Specificity=0.9956
#     Label 6: TN=2794, FP=84, Specificity=0.9708
#     Label 7: TN=2652, FP=84, Specificity=0.9693
#     Label 8: TN=2779, FP=56, Specificity=0.9802
#     Label 9: TN=2704, FP=69, Specificity=0.9751
#     Label 10: TN=2743, FP=51, Specificity=0.9817
#     Label 11: TN=2477, FP=127, Specificity=0.9512
#     Label 12: TN=2965, FP=16, Specificity=0.9946
#     Label 13: TN=2529, FP=147, Specificity=0.9451
#   Fold 2 average specificity: 0.9779
#   Fold 3: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_0\confusion_matrix\confusion_matrix_best_f1_3.json
#     Label 0: TN=2255, FP=124, Specificity=0.9479
#     Label 1: TN=2956, FP=7, Specificity=0.9976
#     Label 2: TN=2900, FP=10, Specificity=0.9966
#     Label 3: TN=2462, FP=78, Specificity=0.9693
#     Label 4: TN=2906, FP=24, Specificity=0.9918
#     Label 5: TN=2907, FP=16, Specificity=0.9945
#     Label 6: TN=2861, FP=16, Specificity=0.9944
#     Label 7: TN=2672, FP=64, Specificity=0.9766
#     Label 8: TN=2790, FP=45, Specificity=0.9841
#     Label 9: TN=2723, FP=50, Specificity=0.9820
#     Label 10: TN=2762, FP=31, Specificity=0.9889
#     Label 11: TN=2467, FP=137, Specificity=0.9474
#     Label 12: TN=2977, FP=3, Specificity=0.9990
#     Label 13: TN=2574, FP=103, Specificity=0.9615
#   Fold 3 average specificity: 0.9808
#   Fold 4: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_0\confusion_matrix\confusion_matrix_best_f1_4.json
#     Label 0: TN=2262, FP=126, Specificity=0.9472
#     Label 1: TN=2957, FP=6, Specificity=0.9980
#     Label 2: TN=2907, FP=3, Specificity=0.9990
#     Label 3: TN=2367, FP=173, Specificity=0.9319
#     Label 4: TN=2876, FP=54, Specificity=0.9816
#     Label 5: TN=2919, FP=4, Specificity=0.9986
#     Label 6: TN=2838, FP=40, Specificity=0.9861
#     Label 7: TN=2589, FP=147, Specificity=0.9463
#     Label 8: TN=2786, FP=49, Specificity=0.9827
#     Label 9: TN=2687, FP=87, Specificity=0.9686
#     Label 10: TN=2776, FP=18, Specificity=0.9936
#     Label 11: TN=2526, FP=78, Specificity=0.9700
#     Label 12: TN=2978, FP=3, Specificity=0.9990
#     Label 13: TN=2623, FP=54, Specificity=0.9798
#   Fold 4 average specificity: 0.9773
#   Fold 5: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_0\confusion_matrix\confusion_matrix_best_f1_5.json
#     Label 0: TN=2320, FP=69, Specificity=0.9711
#     Label 1: TN=2946, FP=17, Specificity=0.9943
#     Label 2: TN=2909, FP=0, Specificity=1.0000
#     Label 3: TN=2429, FP=111, Specificity=0.9563
#     Label 4: TN=2864, FP=65, Specificity=0.9778
#     Label 5: TN=2890, FP=33, Specificity=0.9887
#     Label 6: TN=2859, FP=18, Specificity=0.9937
#     Label 7: TN=2642, FP=93, Specificity=0.9660
#     Label 8: TN=2829, FP=5, Specificity=0.9982
#     Label 9: TN=2684, FP=89, Specificity=0.9679
#     Label 10: TN=2683, FP=111, Specificity=0.9603
#     Label 11: TN=2397, FP=207, Specificity=0.9205
#     Label 12: TN=2959, FP=22, Specificity=0.9926
#     Label 13: TN=2606, FP=71, Specificity=0.9735
#   Fold 5 average specificity: 0.9758
# Seed 0 average specificity across folds: 0.9778
#
# Processing seed 1
#   Fold 1: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_1\confusion_matrix\confusion_matrix_best_f1_1.json
#     Label 0: TN=2282, FP=107, Specificity=0.9552
#     Label 1: TN=2954, FP=8, Specificity=0.9973
#     Label 2: TN=2908, FP=1, Specificity=0.9997
#     Label 3: TN=2514, FP=26, Specificity=0.9898
#     Label 4: TN=2866, FP=63, Specificity=0.9785
#     Label 5: TN=2827, FP=96, Specificity=0.9672
#     Label 6: TN=2775, FP=102, Specificity=0.9645
#     Label 7: TN=2652, FP=83, Specificity=0.9697
#     Label 8: TN=2829, FP=6, Specificity=0.9979
#     Label 9: TN=2718, FP=55, Specificity=0.9802
#     Label 10: TN=2745, FP=48, Specificity=0.9828
#     Label 11: TN=2491, FP=112, Specificity=0.9570
#     Label 12: TN=2981, FP=0, Specificity=1.0000
#     Label 13: TN=2522, FP=154, Specificity=0.9425
#   Fold 1 average specificity: 0.9773
#   Fold 2: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_1\confusion_matrix\confusion_matrix_best_f1_2.json
#     Label 0: TN=2329, FP=59, Specificity=0.9753
#     Label 1: TN=2945, FP=18, Specificity=0.9939
#     Label 2: TN=2899, FP=11, Specificity=0.9962
#     Label 3: TN=2464, FP=76, Specificity=0.9701
#     Label 4: TN=2905, FP=24, Specificity=0.9918
#     Label 5: TN=2909, FP=13, Specificity=0.9956
#     Label 6: TN=2794, FP=84, Specificity=0.9708
#     Label 7: TN=2652, FP=84, Specificity=0.9693
#     Label 8: TN=2779, FP=56, Specificity=0.9802
#     Label 9: TN=2704, FP=69, Specificity=0.9751
#     Label 10: TN=2743, FP=51, Specificity=0.9817
#     Label 11: TN=2477, FP=127, Specificity=0.9512
#     Label 12: TN=2965, FP=16, Specificity=0.9946
#     Label 13: TN=2529, FP=147, Specificity=0.9451
#   Fold 2 average specificity: 0.9779
#   Fold 3: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_1\confusion_matrix\confusion_matrix_best_f1_3.json
#     Label 0: TN=2255, FP=124, Specificity=0.9479
#     Label 1: TN=2956, FP=7, Specificity=0.9976
#     Label 2: TN=2900, FP=10, Specificity=0.9966
#     Label 3: TN=2462, FP=78, Specificity=0.9693
#     Label 4: TN=2906, FP=24, Specificity=0.9918
#     Label 5: TN=2907, FP=16, Specificity=0.9945
#     Label 6: TN=2861, FP=16, Specificity=0.9944
#     Label 7: TN=2672, FP=64, Specificity=0.9766
#     Label 8: TN=2790, FP=45, Specificity=0.9841
#     Label 9: TN=2723, FP=50, Specificity=0.9820
#     Label 10: TN=2762, FP=31, Specificity=0.9889
#     Label 11: TN=2467, FP=137, Specificity=0.9474
#     Label 12: TN=2977, FP=3, Specificity=0.9990
#     Label 13: TN=2574, FP=103, Specificity=0.9615
#   Fold 3 average specificity: 0.9808
#   Fold 4: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_1\confusion_matrix\confusion_matrix_best_f1_4.json
#     Label 0: TN=2262, FP=126, Specificity=0.9472
#     Label 1: TN=2957, FP=6, Specificity=0.9980
#     Label 2: TN=2907, FP=3, Specificity=0.9990
#     Label 3: TN=2367, FP=173, Specificity=0.9319
#     Label 4: TN=2876, FP=54, Specificity=0.9816
#     Label 5: TN=2919, FP=4, Specificity=0.9986
#     Label 6: TN=2838, FP=40, Specificity=0.9861
#     Label 7: TN=2589, FP=147, Specificity=0.9463
#     Label 8: TN=2786, FP=49, Specificity=0.9827
#     Label 9: TN=2687, FP=87, Specificity=0.9686
#     Label 10: TN=2776, FP=18, Specificity=0.9936
#     Label 11: TN=2526, FP=78, Specificity=0.9700
#     Label 12: TN=2978, FP=3, Specificity=0.9990
#     Label 13: TN=2623, FP=54, Specificity=0.9798
#   Fold 4 average specificity: 0.9773
#   Fold 5: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_FLC\no_nosamp\seed_1\confusion_matrix\confusion_matrix_best_f1_5.json
#     Label 0: TN=2320, FP=69, Specificity=0.9711
#     Label 1: TN=2946, FP=17, Specificity=0.9943
#     Label 2: TN=2909, FP=0, Specificity=1.0000
#     Label 3: TN=2429, FP=111, Specificity=0.9563
#     Label 4: TN=2864, FP=65, Specificity=0.9778
#     Label 5: TN=2890, FP=33, Specificity=0.9887
#     Label 6: TN=2859, FP=18, Specificity=0.9937
#     Label 7: TN=2642, FP=93, Specificity=0.9660
#     Label 8: TN=2829, FP=5, Specificity=0.9982
#     Label 9: TN=2684, FP=89, Specificity=0.9679
#     Label 10: TN=2683, FP=111, Specificity=0.9603
#     Label 11: TN=2397, FP=207, Specificity=0.9205
#     Label 12: TN=2959, FP=22, Specificity=0.9926
#     Label 13: TN=2606, FP=71, Specificity=0.9735
#   Fold 5 average specificity: 0.9758
# Seed 1 average specificity across folds: 0.9778
#
# Final result: Specificity = 0.9778 ± 0.0000

# %% [markdown]
# # Calculate Specificity for Multi-Label dataset

# %%
import json
from pathlib import Path
import numpy as np

base_path = Path(r"C:/Users/Admin/Documents/MasterThesis/results/VinBigData/ResNet_Bcos_Blur/light_oversamp")
all_seed_fold_specificities = []

for seed in [0, 1]:
    print(f"\nProcessing seed {seed}")
    seed_specificities = []
    for fold in range(1, 6):
        file_path = base_path / f"seed_{seed}" / "confusion_matrix" / f"confusion_matrix_best_recall_{fold}.json"
        print(f"  Fold {fold}: {file_path}")
        try:
            with open(file_path, 'r') as f:
                data = json.load(f)
                confusion_matrices = data["confusion_matrices"]
                per_label_specificities = []
                for idx, cm in enumerate(confusion_matrices):
                    tn = cm[0][0]
                    fp = cm[0][1]
                    denom = tn + fp
                    specificity = tn / denom if denom != 0 else float('nan')
                    per_label_specificities.append(specificity)
                    print(f"    Label {idx}: TN={tn}, FP={fp}, Specificity={specificity:.4f}")
                fold_avg = np.nanmean(per_label_specificities)
                print(f"  Fold {fold} average specificity: {fold_avg:.4f}")
                seed_specificities.append(fold_avg)
        except FileNotFoundError:
            print(f"    File not found: {file_path}")
            continue
    if seed_specificities:
        seed_avg = np.nanmean(seed_specificities)
        print(f"Seed {seed} average specificity across folds: {seed_avg:.4f}")
        all_seed_fold_specificities.append(seed_avg)
    else:
        print(f"  No valid folds for seed {seed}")

if all_seed_fold_specificities:
    mean_spec = np.nanmean(all_seed_fold_specificities)
    std_spec = np.nanstd(all_seed_fold_specificities, ddof=1) if len(all_seed_fold_specificities) > 1 else 0.0
    print(f"\nFinal result: Specificity = {mean_spec:.4f} ± {std_spec:.4f}")
else:
    print("\nNo specificity values could be calculated because all files are missing.")
# Out:
# Processing seed 0
#   Fold 1: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_0\confusion_matrix\confusion_matrix_best_recall_1.json
#     Label 0: TN=1909, FP=480, Specificity=0.7991
#     Label 1: TN=2925, FP=37, Specificity=0.9875
#     Label 2: TN=1595, FP=1314, Specificity=0.5483
#     Label 3: TN=2094, FP=446, Specificity=0.8244
#     Label 4: TN=2851, FP=78, Specificity=0.9734
#     Label 5: TN=2495, FP=428, Specificity=0.8536
#     Label 6: TN=2801, FP=76, Specificity=0.9736
#     Label 7: TN=1796, FP=939, Specificity=0.6567
#     Label 8: TN=2520, FP=315, Specificity=0.8889
#     Label 9: TN=2288, FP=485, Specificity=0.8251
#     Label 10: TN=2453, FP=340, Specificity=0.8783
#     Label 11: TN=1821, FP=782, Specificity=0.6996
#     Label 12: TN=2977, FP=4, Specificity=0.9987
#     Label 13: TN=1936, FP=740, Specificity=0.7235
#   Fold 1 average specificity: 0.8307
#   Fold 2: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_0\confusion_matrix\confusion_matrix_best_recall_2.json
#     Label 0: TN=1715, FP=673, Specificity=0.7182
#     Label 1: TN=2942, FP=21, Specificity=0.9929
#     Label 2: TN=2622, FP=288, Specificity=0.9010
#     Label 3: TN=2012, FP=528, Specificity=0.7921
#     Label 4: TN=2875, FP=54, Specificity=0.9816
#     Label 5: TN=2863, FP=59, Specificity=0.9798
#     Label 6: TN=2817, FP=61, Specificity=0.9788
#     Label 7: TN=2405, FP=331, Specificity=0.8790
#     Label 8: TN=2518, FP=317, Specificity=0.8882
#     Label 9: TN=2083, FP=690, Specificity=0.7512
#     Label 10: TN=2507, FP=287, Specificity=0.8973
#     Label 11: TN=1863, FP=741, Specificity=0.7154
#     Label 12: TN=2967, FP=14, Specificity=0.9953
#     Label 13: TN=2090, FP=586, Specificity=0.7810
#   Fold 2 average specificity: 0.8751
#   Fold 3: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_0\confusion_matrix\confusion_matrix_best_recall_3.json
#     Label 0: TN=1045, FP=1334, Specificity=0.4393
#     Label 1: TN=2718, FP=245, Specificity=0.9173
#     Label 2: TN=2910, FP=0, Specificity=1.0000
#     Label 3: TN=1632, FP=908, Specificity=0.6425
#     Label 4: TN=837, FP=2093, Specificity=0.2857
#     Label 5: TN=2923, FP=0, Specificity=1.0000
#     Label 6: TN=2194, FP=683, Specificity=0.7626
#     Label 7: TN=133, FP=2603, Specificity=0.0486
#     Label 8: TN=1973, FP=862, Specificity=0.6959
#     Label 9: TN=2144, FP=629, Specificity=0.7732
#     Label 10: TN=2742, FP=51, Specificity=0.9817
#     Label 11: TN=1736, FP=868, Specificity=0.6667
#     Label 12: TN=1478, FP=1502, Specificity=0.4960
#     Label 13: TN=2010, FP=667, Specificity=0.7508
#   Fold 3 average specificity: 0.6757
#   Fold 4: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_0\confusion_matrix\confusion_matrix_best_recall_4.json
#     Label 0: TN=1863, FP=525, Specificity=0.7802
#     Label 1: TN=2941, FP=22, Specificity=0.9926
#     Label 2: TN=796, FP=2114, Specificity=0.2735
#     Label 3: TN=2227, FP=313, Specificity=0.8768
#     Label 4: TN=2920, FP=10, Specificity=0.9966
#     Label 5: TN=2915, FP=8, Specificity=0.9973
#     Label 6: TN=2876, FP=2, Specificity=0.9993
#     Label 7: TN=2273, FP=463, Specificity=0.8308
#     Label 8: TN=2146, FP=689, Specificity=0.7570
#     Label 9: TN=2031, FP=743, Specificity=0.7322
#     Label 10: TN=2581, FP=213, Specificity=0.9238
#     Label 11: TN=667, FP=1937, Specificity=0.2561
#     Label 12: TN=2978, FP=3, Specificity=0.9990
#     Label 13: TN=1630, FP=1047, Specificity=0.6089
#   Fold 4 average specificity: 0.7874
#   Fold 5: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_0\confusion_matrix\confusion_matrix_best_recall_5.json
#     Label 0: TN=1078, FP=1311, Specificity=0.4512
#     Label 1: TN=2952, FP=11, Specificity=0.9963
#     Label 2: TN=2090, FP=819, Specificity=0.7185
#     Label 3: TN=1696, FP=844, Specificity=0.6677
#     Label 4: TN=2806, FP=123, Specificity=0.9580
#     Label 5: TN=2485, FP=438, Specificity=0.8502
#     Label 6: TN=2432, FP=445, Specificity=0.8453
#     Label 7: TN=1125, FP=1610, Specificity=0.4113
#     Label 8: TN=1915, FP=919, Specificity=0.6757
#     Label 9: TN=2501, FP=272, Specificity=0.9019
#     Label 10: TN=2675, FP=119, Specificity=0.9574
#     Label 11: TN=810, FP=1794, Specificity=0.3111
#     Label 12: TN=2977, FP=4, Specificity=0.9987
#     Label 13: TN=1717, FP=960, Specificity=0.6414
#   Fold 5 average specificity: 0.7418
# Seed 0 average specificity across folds: 0.7822
#
# Processing seed 1
#   Fold 1: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_1\confusion_matrix\confusion_matrix_best_recall_1.json
#     Label 0: TN=1762, FP=627, Specificity=0.7375
#     Label 1: TN=2073, FP=889, Specificity=0.6999
#     Label 2: TN=2853, FP=56, Specificity=0.9807
#     Label 3: TN=1642, FP=898, Specificity=0.6465
#     Label 4: TN=2660, FP=269, Specificity=0.9082
#     Label 5: TN=2775, FP=148, Specificity=0.9494
#     Label 6: TN=2248, FP=629, Specificity=0.7814
#     Label 7: TN=2129, FP=606, Specificity=0.7784
#     Label 8: TN=2826, FP=9, Specificity=0.9968
#     Label 9: TN=1474, FP=1299, Specificity=0.5316
#     Label 10: TN=2524, FP=269, Specificity=0.9037
#     Label 11: TN=1693, FP=910, Specificity=0.6504
#     Label 12: TN=2848, FP=133, Specificity=0.9554
#     Label 13: TN=410, FP=2266, Specificity=0.1532
#   Fold 1 average specificity: 0.7624
#   Fold 2: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_1\confusion_matrix\confusion_matrix_best_recall_2.json
#     Label 0: TN=1657, FP=731, Specificity=0.6939
#     Label 1: TN=2837, FP=126, Specificity=0.9575
#     Label 2: TN=2829, FP=81, Specificity=0.9722
#     Label 3: TN=2417, FP=123, Specificity=0.9516
#     Label 4: TN=1761, FP=1168, Specificity=0.6012
#     Label 5: TN=2620, FP=302, Specificity=0.8966
#     Label 6: TN=1401, FP=1477, Specificity=0.4868
#     Label 7: TN=432, FP=2304, Specificity=0.1579
#     Label 8: TN=2818, FP=17, Specificity=0.9940
#     Label 9: TN=2170, FP=603, Specificity=0.7825
#     Label 10: TN=2700, FP=94, Specificity=0.9664
#     Label 11: TN=2171, FP=433, Specificity=0.8337
#     Label 12: TN=2740, FP=241, Specificity=0.9192
#     Label 13: TN=1862, FP=814, Specificity=0.6958
#   Fold 2 average specificity: 0.7792
#   Fold 3: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_1\confusion_matrix\confusion_matrix_best_recall_3.json
#     Label 0: TN=1706, FP=673, Specificity=0.7171
#     Label 1: TN=2948, FP=15, Specificity=0.9949
#     Label 2: TN=2596, FP=314, Specificity=0.8921
#     Label 3: TN=1965, FP=575, Specificity=0.7736
#     Label 4: TN=2882, FP=48, Specificity=0.9836
#     Label 5: TN=2852, FP=71, Specificity=0.9757
#     Label 6: TN=2699, FP=178, Specificity=0.9381
#     Label 7: TN=2340, FP=396, Specificity=0.8553
#     Label 8: TN=2352, FP=483, Specificity=0.8296
#     Label 9: TN=2240, FP=533, Specificity=0.8078
#     Label 10: TN=2642, FP=151, Specificity=0.9459
#     Label 11: TN=1741, FP=863, Specificity=0.6686
#     Label 12: TN=2977, FP=3, Specificity=0.9990
#     Label 13: TN=2029, FP=648, Specificity=0.7579
#   Fold 3 average specificity: 0.8671
#   Fold 4: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_1\confusion_matrix\confusion_matrix_best_recall_4.json
#     Label 0: TN=1851, FP=537, Specificity=0.7751
#     Label 1: TN=2961, FP=2, Specificity=0.9993
#     Label 2: TN=2869, FP=41, Specificity=0.9859
#     Label 3: TN=2212, FP=328, Specificity=0.8709
#     Label 4: TN=2919, FP=11, Specificity=0.9962
#     Label 5: TN=1594, FP=1329, Specificity=0.5453
#     Label 6: TN=1509, FP=1369, Specificity=0.5243
#     Label 7: TN=2640, FP=96, Specificity=0.9649
#     Label 8: TN=2772, FP=63, Specificity=0.9778
#     Label 9: TN=1342, FP=1432, Specificity=0.4838
#     Label 10: TN=2747, FP=47, Specificity=0.9832
#     Label 11: TN=2385, FP=219, Specificity=0.9159
#     Label 12: TN=2966, FP=15, Specificity=0.9950
#     Label 13: TN=1308, FP=1369, Specificity=0.4886
#   Fold 4 average specificity: 0.8219
#   Fold 5: C:\Users\Admin\Documents\MasterThesis\results\VinBigData\ResNet_Bcos_Blur\light_oversamp\seed_1\confusion_matrix\confusion_matrix_best_recall_5.json
#     Label 0: TN=1147, FP=1242, Specificity=0.4801
#     Label 1: TN=2844, FP=119, Specificity=0.9598
#     Label 2: TN=2522, FP=387, Specificity=0.8670
#     Label 3: TN=2019, FP=521, Specificity=0.7949
#     Label 4: TN=2888, FP=41, Specificity=0.9860
#     Label 5: TN=2263, FP=660, Specificity=0.7742
#     Label 6: TN=2694, FP=183, Specificity=0.9364
#     Label 7: TN=2066, FP=669, Specificity=0.7554
#     Label 8: TN=2675, FP=159, Specificity=0.9439
#     Label 9: TN=1494, FP=1279, Specificity=0.5388
#     Label 10: TN=2167, FP=627, Specificity=0.7756
#     Label 11: TN=1331, FP=1273, Specificity=0.5111
#     Label 12: TN=2981, FP=0, Specificity=1.0000
#     Label 13: TN=1454, FP=1223, Specificity=0.5431
#   Fold 5 average specificity: 0.7762
# Seed 1 average specificity across folds: 0.8013
#
# Final result: Specificity = 0.7918 ± 0.0136
