# %%
import math
from typing import Any, Callable, List, Optional, Type, Union

import torch.nn as nn
from resnet import resnet50

resnet50(False,True) # problem with architecture here - vastly different!
# Out:
# BcosResNet(
#   (conv1): BcosConv2d(
#     B=2,
#     (linear): NormedConv2d(6, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   )
#   (pool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#   (bn1): DetachablePositionNorm2dNoBias((64,), eps=1e-05, elementwise_affine=True)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): DetachablePositionNorm2dNoBias((64,), eps=1e-05, elementwise_affine=True)
#       (conv2): BcosConv2d(
#         B=2,
#         (linear): NormedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn2): DetachablePositionNorm2dNoBias((64,), eps=1e-05, elementwise_affine=True)
#       (bn3): DetachablePositionNorm2dNoBias((256,), eps=1e-05, elementwise_affine=True)
#       (downsample): Sequential(
#         (0): None
#         (1): DetachablePositionNorm2dNoBias((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (1): Bottleneck(
# ...
