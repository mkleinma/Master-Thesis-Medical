# %%
## Supportive Methods

def pred_count(list):
    zeroCount = 0
    oneCount = 0
    
    for element in list:
        if element == 0:
            zeroCount += 1
        elif element == 1:
            oneCount += 1
    
    return zeroCount, oneCount


def overlap_lists(list1, list2):
    count = 0
    for index in range(len(list1)):
        if (list1[index] == list2[index]):
            count += 1
    
    percentage = count/32
    #print(f"Overlap percentage: {percentage}")
    
        
        

def remove_module_prefix(state_dict):
    new_state_dict = {}
    for k, v in state_dict.items():
        if k.startswith('module.'):
            new_key = k[7:] 
            new_state_dict[new_key] = v
        else:
            new_state_dict[k] = v
    return new_state_dict

# %%
import os
import pickle
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, accuracy_score
import numpy as np
import pandas as pd
from torchvision.transforms import functional as TF
from PIL import Image
from bcosconv2d import NormedConv2d
import pydicom 
import random
import matplotlib.pyplot as plt


np.random.seed(0)
random.seed(0)
torch.manual_seed(0)

class PneumoniaDataset(Dataset):
    def __init__(self, dataframe, image_folder, transform=None):
        self.data = dataframe
        self.image_folder = image_folder
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        image_path = os.path.join(self.image_folder, f"{row['patientId']}.dcm")
        label = row['Target']
        
        dicom = pydicom.dcmread(image_path)
        image = dicom.pixel_array
        
        image = Image.fromarray(image).convert("RGB")
        tensor_image = TF.to_tensor(image)
        six_channel_image = torch.cat([tensor_image, 1-tensor_image], dim=0) 
                
        return six_channel_image, torch.tensor(label, dtype=torch.float32)
    
# Paths
csv_path = r"C:\Users\Admin\Documents\rsna-pneumonia-detection-challenge\stage_2_train_labels.csv"
image_folder = r"C:\Users\Admin\Documents\rsna-pneumonia-detection-challenge\stage_2_train_images"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Pneumonia\training\splits\splits_balanced.pkl"
model_path = r"C:\Users\Admin\Documents\MasterThesis\pneumonia_detection_model_fold_1.pth" # old: bcos_csv

data = pd.read_csv(csv_path)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load model
model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
model.fc.linear = NormedConv2d(2048, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
state_dict = torch.load(model_path, map_location=device)
#fixed_dict = remove_module_prefix(state_dict)
model.load_state_dict(state_dict)
model = model.to(device)
model.eval()


# Transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])




# Evaluate model on the 5th split
def evaluate_model_on_fifth_split(model, data, split, image_folder, transform, device):
    val_idx = split[1]  # Only use the validation indices from the 5th split
    val_data = data.iloc[val_idx]
    val_dataset = PneumoniaDataset(val_data, image_folder, transform=transform)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    all_labels = []
    all_preds = []
    all_probs = []
    
    print("Counting probs/preds")
    count = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device).unsqueeze(1)
            
            print("Before Output")
            # Model predictions
            outputs = model(images)  # Logits
            print("Output {count}")
            count+=1
            probs = torch.sigmoid(outputs)  # Probabilities
            preds = torch.round(torch.sigmoid(outputs))  # Binary predictions
            
            #zeroCountPred, oneCountPred = pred_count(preds)
            #zeroCountLabel, oneCountLabel = pred_count(labels)
            ## Debug
            #print(f"Prediction counts: {zeroCountPred} and {oneCountPred}")
            #print(f"Label counts: {zeroCountLabel} and {oneCountLabel}")
            
            #overlap_lists(preds, labels)
            

            # Collect predictions and labels
            all_labels.extend(labels.cpu().numpy().flatten())
            all_preds.extend(preds.cpu().numpy().flatten())
            all_probs.extend(probs.cpu().numpy().flatten())
            
            del images, labels, outputs, probs, preds
            torch.cuda.empty_cache()

            
        print("Calculating metrics")
        accuracy = accuracy_score(all_labels, all_preds)
        precision = precision_score(all_labels, all_preds)
        recall = recall_score(all_labels, all_preds)
        f1 = f1_score(all_labels, all_preds)
        auc = roc_auc_score(all_labels, all_probs)
        cm = confusion_matrix(all_labels, all_preds)                
        return cm, precision, recall, f1, auc, accuracy

# Specify the 5th split
fifth_split = splits[0]  # Index 4 corresponds to the 5th fold

# Run evaluation
cm, precision, recall, f1, auc, accuracy = evaluate_model_on_fifth_split(
    model=model,
    data=data,
    split=fifth_split,
    image_folder=image_folder,
    transform=transform,
    device=device
)

# Print results
print("Evaluation Metrics for the 1st Split:")
print(f"Confusion Matrix:\n{cm}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"AUC: {auc:.4f}")
# Out:
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
# Counting probs/preds
# Before Output
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 134
#     131 fifth_split = splits[0]  # Index 4 corresponds to the 5th fold
#     133 # Run evaluation
# --> 134 cm, precision, recall, f1, auc, accuracy = evaluate_model_on_fifth_split(
#     135     model=model,
#     136     data=data,
#     137     split=fifth_split,
#     138     image_folder=image_folder,
#     139     transform=transform,
#     140     device=device
#     141 )
#     143 # Print results
#     144 print("Evaluation Metrics for the 1st Split:")
#
# Cell In[2], line 97, in evaluate_model_on_fifth_split(model, data, split, image_folder, transform, device)
#      95 print("Before Output")
#      96 # Model predictions
# ---> 97 outputs = model(images)  # Logits
#      98 print("Output {count}")
#      99 count+=1
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache\torch\hub\B-cos_B-cos-v2_main\bcos\models\resnet.py:461, in BcosResNet.forward(self, x)
#     460 def forward(self, x):
# --> 461     x = self.forward_features(x)
#     463     x = self.fc(x)
#     464     x = self.avgpool(x)
#
# File ~/.cache\torch\hub\B-cos_B-cos-v2_main\bcos\models\resnet.py:454, in BcosResNet.forward_features(self, x)
#     451     x = self.pool(x)
#     453 x = self.layer1(x)
# --> 454 x = self.layer2(x)
#     455 x = self.layer3(x)
#     456 if self.layer4 is not None:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache\torch\hub\B-cos_B-cos-v2_main\bcos\models\resnet.py:221, in Bottleneck.forward(self, x)
#     218 out = self.bn1(out)
#     219 # out = self.act(out)
# --> 221 out = self.conv2(out)
#     222 out = self.bn2(out)
#     223 # out = self.act(out)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache\torch\hub\B-cos_B-cos-v2_main\bcos\modules\bcosconv2d.py:136, in BcosConv2d.forward(self, in_tensor)
#     127 def forward(self, in_tensor: Tensor) -> Tensor:
#     128     """
#     129     Forward pass implementation.
#     130     Args:
#    (...)
#     134         BcosConv2d output on the input tensor.
#     135     """
# --> 136     return self.forward_impl(in_tensor)
#
# File ~/.cache\torch\hub\B-cos_B-cos-v2_main\bcos\modules\bcosconv2d.py:148, in BcosConv2d.forward_impl(self, in_tensor)
#     139 """
#     140 Forward pass.
#     141 Args:
#    (...)
#     145     BcosConv2d output on the input tensor.
#     146 """
#     147 # Simple linear layer
# --> 148 out = self.linear(in_tensor)
#     150 # MaxOut computation
#     151 if self.max_out > 1:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache\torch\hub\B-cos_B-cos-v2_main\bcos\modules\bcosconv2d.py:23, in NormedConv2d.forward(self, in_tensor)
#      21 def forward(self, in_tensor: Tensor) -> Tensor:
#      22     w = self.weight / LA.vector_norm(self.weight, dim=(1, 2, 3), keepdim=True)
# ---> 23     return self._conv_forward(input=in_tensor, weight=w, bias=self.bias)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
import os
import pickle
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np
import pandas as pd
from torchvision.transforms import functional as TF
from PIL import Image
from bcosconv2d import NormedConv2d  # Replace with your implementation of NormedConv2d
import pydicom 
import random
import matplotlib.pyplot as plt


np.random.seed(0)
random.seed(0)
torch.manual_seed(0)

class PneumoniaDataset(Dataset):
    def __init__(self, dataframe, image_folder, transform=None):
        self.data = dataframe
        self.image_folder = image_folder
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        image_path = os.path.join(self.image_folder, f"{row['patientId']}.dcm")
        label = row['Target']
        
        dicom = pydicom.dcmread(image_path)
        image = dicom.pixel_array
        
        image = Image.fromarray(image).convert("RGB")
        tensor_image = TF.to_tensor(image)
        six_channel_image = torch.cat([tensor_image, 1-tensor_image], dim=0) # according
                
        return six_channel_image, torch.tensor(label, dtype=torch.float32)
    
# Paths
csv_path = r"C:\Users\Admin\Documents\rsna-pneumonia-detection-challenge\stage_2_train_labels.csv"
image_folder = r"C:\Users\Admin\Documents\rsna-pneumonia-detection-challenge\stage_2_train_images"
splits_path = r"G:\Meine Ablage\Universität\Master Thesis\Pneumonia\training\splits\splits_balanced.pkl"
model_path = r"C:\Users\Admin\Documents\MasterThesis\pneumonia_detection_model_fold_1.pth"

data = pd.read_csv(csv_path)
with open(splits_path, 'rb') as f:
    splits = pickle.load(f)
    

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load model
model = torch.hub.load('B-cos/B-cos-v2', 'resnet50', pretrained=True)
model.fc.linear = NormedConv2d(2048, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)

state_dict = torch.load(model_path, map_location=device)
fixed_dict = remove_module_prefix(state_dict)
model.load_state_dict(fixed_dict)
model = model.to(device)
model.eval()


# Transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])




# Evaluate model on the 5th split
def evaluate_model_on_fifth_split(model, data, split, image_folder, transform, device):
    val_idx = split[1]  # Only use the validation indices from the 5th split
    val_data = data.iloc[val_idx]
    val_dataset = PneumoniaDataset(val_data, image_folder, transform=transform)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    all_labels = []
    all_preds = []
    all_probs = []
    
    tp_count = 0
    tn_count = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device).unsqueeze(1)
            # Model predictions
            outputs = model(images)  # Logits
            probs = torch.sigmoid(outputs)  # Probabilities
            preds = torch.round(torch.sigmoid(outputs))  # Binary predictions
            
            #zeroCountPred, oneCountPred = pred_count(preds)
            #zeroCountLabel, oneCountLabel = pred_count(labels)
            ## Debug
            #print(f"Prediction counts: {zeroCountPred} and {oneCountPred}")
            #print(f"Label counts: {zeroCountLabel} and {oneCountLabel}")
            

            # Collect predictions and labels
            all_labels.extend(labels.cpu().numpy().flatten())
            all_preds.extend(preds.cpu().numpy().flatten())
            all_probs.extend(probs.cpu().numpy().flatten())
            
            
            #for i in range(len(labels)):
            #
            # if labels[i] == 0 and preds[i] == 0:  # True Negative
            #        if (tn_count < 5):
            #           print(f"Displaying TN Image {tn_count}")
            #            usedImage = pil_images[i]
            #            usedImage = usedImage[None]
            #            expl = model.explain(usedImage)
            #            print("Prediction:", expl["prediction"])
            #            plt.imshow(expl["explanation"])
            #            plt.show()
            #            tn_count += 1
            #    elif labels[i] == 1 and preds[i] == 1:  # True Positive
            #        if (tp_count < 5):
            #            usedImage = pil_images[i]
            #            usedImage = usedImage[None]
            #            print(f"Displaying TP Image {tp_count}")
            #            expl = model.explain(usedImage)
            #            print("Prediction:", expl["prediction"])
            #            plt.imshow(expl["explanation"])
            #            tp_count +=1
    
        print("Calculating metrics")
        accuracy = accuracy(all_labels, all_preds)
        precision = precision_score(all_labels, all_preds)
        recall = recall_score(all_labels, all_preds)
        f1 = f1_score(all_labels, all_preds)
        auc = roc_auc_score(all_labels, all_probs)
        cm = confusion_matrix(all_labels, all_preds)                

    return cm, precision, recall, f1, auc, accuracy

# Specify the 5th split
fifth_split = splits[4]  # Index 4 corresponds to the 5th fold

# Run evaluation
cm, precision, recall, f1, auc, accuracy = evaluate_model_on_fifth_split(
    model=model,
    data=data,
    split=fifth_split,
    image_folder=image_folder,
    transform=transform,
    device=device
)

# Print results
print("Evaluation Metrics for the 5th Split:")
print(f"Confusion Matrix:\n{cm}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"AUC: {auc:.4f}")
# Out:
# Using cache found in C:\Users\Admin/.cache\torch\hub\B-cos_B-cos-v2_main
